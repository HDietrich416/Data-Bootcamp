# %% [markdown]
# # WeatherPy
# ----

# %% [markdown]
# ###   Analysis:
#
# * As cities approach the equator (Latitude = 0), they have a higher maximum temperature.
# * There is not a strong correlation between latitude and either humidity, cloudiness, or windspeed.
# * In the northern hemisphere on the date that the data was pulled (Oct 30, 2020) there is a high proportion of cities with humidity of greater than 60%.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

from pprint import pprint

# Import API key
weather_api_key = "4b0e3b0aab2982b37f2f4173ef8a6955"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 595

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?'
units = "imperial"
lat = []
lng = []
max_temp =[]
humidity = []
cloud = []
wind_speed = []
country = []
date = []
city_name = []
x = 1

for city in cities:
    try:
        query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
        response = requests.get(query_url).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        city_name.append(response['name'])
        print(f"Processing Record {x} of {len(cities)} | {city}")
    except:
        print("City not found. Skipping....")
    x=x+1

print("--------------------------------")
print("Data Retrieval Complete")
print("--------------------------------")
# Out:
# Processing Record 1 of 595 | rikitea
# Processing Record 2 of 595 | hermanus
# Processing Record 3 of 595 | bluff
# Processing Record 4 of 595 | kapaa
# Processing Record 5 of 595 | knysna
# City not found. Skipping....
# Processing Record 7 of 595 | torbay
# Processing Record 8 of 595 | flinders
# Processing Record 9 of 595 | hobart
# Processing Record 10 of 595 | bonfim
# Processing Record 11 of 595 | albany
# Processing Record 12 of 595 | ambilobe
# Processing Record 13 of 595 | vetlanda
# Processing Record 14 of 595 | georgetown
# Processing Record 15 of 595 | krym
# Processing Record 16 of 595 | emerald
# Processing Record 17 of 595 | tautira
# Processing Record 18 of 595 | gorin
# Processing Record 19 of 595 | pisco
# Processing Record 20 of 595 | hasaki
# Processing Record 21 of 595 | avarua
# Processing Record 22 of 595 | miracatu
# Processing Record 23 of 595 | grimstad
# Processing Record 24 of 595 | ushuaia
# Processing Record 25 of 595 | barrow
# Processing Record 26 of 595 | kindu
# Processing Record 27 of 595 | korem
# Processing Record 28 of 595 | clyde river
# Processing Record 29 of 595 | mao
# Processing Record 30 of 595 | coquimbo
# Processing Record 31 of 595 | faanui
# Processing Record 32 of 595 | busselton
# Processing Record 33 of 595 | urbano santos
# Processing Record 34 of 595 | mahebourg
# Processing Record 35 of 595 | hualmay
# Processing Record 36 of 595 | punta arenas
# Processing Record 37 of 595 | codrington
# Processing Record 38 of 595 | nikolskoye
# Processing Record 39 of 595 | kutum
# Processing Record 40 of 595 | new norfolk
# Processing Record 41 of 595 | lebu
# Processing Record 42 of 595 | chuzhou
# Processing Record 43 of 595 | kloulklubed
# Processing Record 44 of 595 | assiniboia
# City not found. Skipping....
# Processing Record 46 of 595 | buala
# Processing Record 47 of 595 | okhotsk
# Processing Record 48 of 595 | broome
# Processing Record 49 of 595 | vardo
# Processing Record 50 of 595 | keetmanshoop
# Processing Record 51 of 595 | kostomuksha
# Processing Record 52 of 595 | chuy
# City not found. Skipping....
# Processing Record 54 of 595 | aksay
# Processing Record 55 of 595 | zabol
# Processing Record 218 of 595 | tuktoyaktuk
# Processing Record 219 of 595 | port hardy
# Processing Record 220 of 595 | kazanskoye
# Processing Record 221 of 595 | cap malheureux
# Processing Record 222 of 595 | angoche
# Processing Record 223 of 595 | varna
# Processing Record 224 of 595 | kotelnich
# Processing Record 225 of 595 | klaksvik
# Processing Record 226 of 595 | tasiilaq
# Processing Record 227 of 595 | henties bay
# Processing Record 228 of 595 | padang
# Processing Record 229 of 595 | bac lieu
# Processing Record 230 of 595 | mansa
# Processing Record 231 of 595 | alice springs
# Processing Record 232 of 595 | abu samrah
# Processing Record 233 of 595 | guerrero negro
# Processing Record 234 of 595 | rio grande
# Processing Record 235 of 595 | itarantim
# Processing Record 236 of 595 | flin flon
# Processing Record 237 of 595 | sakakah
# Processing Record 238 of 595 | sioux lookout
# Processing Record 239 of 595 | kavieng
# Processing Record 240 of 595 | ornskoldsvik
# Processing Record 241 of 595 | kismayo
# Processing Record 242 of 595 | faya
# Processing Record 243 of 595 | mount gambier
# Processing Record 244 of 595 | saiha
# Processing Record 245 of 595 | vila velha
# Processing Record 246 of 595 | pindorama
# Processing Record 247 of 595 | kodiak
# Processing Record 248 of 595 | jabinyanah
# Processing Record 249 of 595 | yellowknife
# Processing Record 250 of 595 | udachnyy
# Processing Record 251 of 595 | matara
# Processing Record 252 of 595 | srednekolymsk
# Processing Record 253 of 595 | isangel
# City not found. Skipping....
# Processing Record 255 of 595 | cooma
# Processing Record 256 of 595 | bukachacha
# Processing Record 257 of 595 | vila franca do campo
# Processing Record 258 of 595 | sur
# Processing Record 259 of 595 | larvik
# Processing Record 260 of 595 | malakal
# Processing Record 261 of 595 | huilong
# Processing Record 262 of 595 | nisia floresta
# Processing Record 263 of 595 | stornoway
# Processing Record 264 of 595 | itupiranga
# Processing Record 265 of 595 | abu kamal
# Processing Record 266 of 595 | bethel
# Processing Record 267 of 595 | los llanos de aridane
# Processing Record 268 of 595 | san juan
# Processing Record 269 of 595 | wanxian
# Processing Record 270 of 595 | saint-philippe
# Processing Record 271 of 595 | pula
# Processing Record 272 of 595 | opuwo
# Processing Record 273 of 595 | meulaboh
# Processing Record 274 of 595 | norman wells
# Processing Record 275 of 595 | zhigansk
# City not found. Skipping....
# Processing Record 277 of 595 | urumqi
# Processing Record 278 of 595 | port augusta
# Processing Record 279 of 595 | lat yao
# Processing Record 280 of 595 | ucluelet
# Processing Record 281 of 595 | northam
# Processing Record 282 of 595 | sao filipe
# Processing Record 283 of 595 | tulun
# Processing Record 284 of 595 | beyneu
# Processing Record 285 of 595 | carora
# Processing Record 286 of 595 | la union
# Processing Record 287 of 595 | srandakan
# Processing Record 288 of 595 | korla
# Processing Record 289 of 595 | honningsvag
# Processing Record 290 of 595 | kristiinankaupunki
# Processing Record 291 of 595 | gusev
# Processing Record 292 of 595 | wakkanai
# Processing Record 293 of 595 | miri
# Processing Record 294 of 595 | rafsanjan
# Processing Record 535 of 595 | havelock
# Processing Record 536 of 595 | pasighat
# Processing Record 537 of 595 | hay river
# Processing Record 538 of 595 | havoysund
# Processing Record 539 of 595 | itarema
# Processing Record 540 of 595 | egvekinot
# Processing Record 541 of 595 | melfort
# Processing Record 542 of 595 | havre-saint-pierre
# Processing Record 543 of 595 | luba
# City not found. Skipping....
# Processing Record 545 of 595 | mongoumba
# Processing Record 546 of 595 | tashla
# Processing Record 547 of 595 | jalingo
# Processing Record 548 of 595 | kandiari
# Processing Record 549 of 595 | abha
# Processing Record 550 of 595 | kapit
# City not found. Skipping....
# City not found. Skipping....
# Processing Record 553 of 595 | gat
# Processing Record 554 of 595 | inhambane
# Processing Record 555 of 595 | kijang
# Processing Record 556 of 595 | sete
# Processing Record 557 of 595 | ngunguru
# Processing Record 558 of 595 | pangnirtung
# Processing Record 559 of 595 | smithers
# Processing Record 560 of 595 | ponta do sol
# Processing Record 561 of 595 | chapeltique
# Processing Record 562 of 595 | vostok
# Processing Record 563 of 595 | pizarro
# Processing Record 564 of 595 | teya
# Processing Record 565 of 595 | darhan
# Processing Record 566 of 595 | bilibino
# Processing Record 567 of 595 | matay
# Processing Record 568 of 595 | maniitsoq
# City not found. Skipping....
# Processing Record 570 of 595 | merrill
# City not found. Skipping....
# Processing Record 572 of 595 | sinjhoro
# Processing Record 573 of 595 | russkiy aktash
# Processing Record 574 of 595 | rorvik
# Processing Record 575 of 595 | saint-georges
# Processing Record 576 of 595 | ati
# Processing Record 577 of 595 | sibu
# Processing Record 578 of 595 | goure
# Processing Record 579 of 595 | kensington
# City not found. Skipping....
# City not found. Skipping....
# Processing Record 582 of 595 | diapaga
# Processing Record 583 of 595 | novo aripuana
# Processing Record 584 of 595 | fort carson
# Processing Record 585 of 595 | nuevo progreso
# Processing Record 586 of 595 | san luis
# City not found. Skipping....
# Processing Record 588 of 595 | ongandjera
# Processing Record 589 of 595 | vanavara
# Processing Record 590 of 595 | indiana
# Processing Record 591 of 595 | mnogovershinnyy
# Processing Record 592 of 595 | kununurra
# City not found. Skipping....
# Processing Record 594 of 595 | beruwala
# Processing Record 595 of 595 | menongue
# --------------------------------
# Data Retrieval Complete
# --------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({"City": city_name, "Lat":lat, "Lng":lng,"Max Temp": max_temp, 
                           "Humidity":humidity, "Cloudiness": cloud, "Wind Speed": wind_speed, 
                          "Country":country, "Date": date})
weather_df.head()
# Out:
#        City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Rikitea -23.12 -134.97     75.63        69           0        8.19
# 1  Hermanus -34.42   19.23     54.00        77           0       11.54
# 2     Bluff -46.60  168.33     55.00        97         100        4.00
# 3     Kapaa  22.08 -159.32     72.00        83          40        6.93
# 4    Knysna -34.04   23.05     55.40        62          20        3.36
#
#   Country        Date
# 0      PF  1604082985
# 1      ZA  1604083146
# 2      NZ  1604083262
# 3      US  1604083262
# 4      ZA  1604083263

# %%
weather_df.to_csv('output.csv', index = False)

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  547.000000  547.000000  547.000000  547.000000  547.000000  547.000000
# mean    21.405503   19.022176   57.485759   71.166362   51.367459    7.768410
# std     33.407157   88.150357   23.116429   21.474828   41.146863    5.629047
# min    -54.800000 -179.170000  -15.360000   11.000000    0.000000    0.450000
# 25%     -6.315000  -59.085000   41.330000   60.000000    1.000000    3.500000
# 50%     26.920000   23.050000   62.010000   76.000000   63.000000    6.260000
# 75%     50.165000   96.250000   76.700000   88.000000   91.500000   10.290000
# max     78.220000  178.420000  100.200000  100.000000  100.000000   33.330000
#
#                Date
# count  5.470000e+02
# mean   1.604083e+09
# std    7.858219e+01
# min    1.604083e+09
# 25%    1.604083e+09
# 50%    1.604083e+09
# 75%    1.604083e+09
# max    1.604083e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
latitude = weather_df['Lat']
temperature = weather_df['Max Temp']

plt.scatter(latitude, temperature, edgecolor = "black")
plt.title("City Latitude vs. Max Temperature (30/10/20)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig('Images/Latitude_vs_ Temp.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
latitude = weather_df['Lat']
humidity = weather_df['Humidity']

plt.scatter(latitude, humidity, facecolor = 'red',edgecolor = "black")
plt.title("City Latitude vs. Humidity (30/10/20)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig('Images/Latitude_vs_ Humidity.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
latitude = weather_df['Lat']
cloudiness = weather_df['Cloudiness']

plt.scatter(latitude, cloudiness, facecolor = 'green',edgecolor = "black")
plt.title("City Latitude vs. Cloudiness (30/10/20)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig('Images/Latitude_vs_ Cloudiness.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
latitude = weather_df['Lat']
wind_speed = weather_df['Wind Speed']

plt.scatter(latitude, wind_speed, facecolor = 'orange',edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (30/10/20)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig('Images/Latitude_vs_ Wind.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
northern_hem = weather_df.loc[weather_df['Lat']>0]
southern_hem = weather_df.loc[weather_df['Lat']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
latitude = northern_hem['Lat']
temperature = northern_hem['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, temperature)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, temperature)
plt.title("Northern Hemisphere - Max Temp vs. Latitude")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(15,-20),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/NH_Latitude_vs_ Temp.png')
plt.show()
# Out:
# The r-value is: 0.7698338362853947

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
latitude = southern_hem['Lat']
temperature = southern_hem['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, temperature)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, temperature)
plt.title("Southern Hemisphere - Max Temp vs. Latitude")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(-20,50),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/SH_Latitude_vs_ Temp.png')
plt.show()
# Out:
# The r-value is: 0.45348526071534895

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
latitude = northern_hem['Lat']
humidity = northern_hem['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, humidity)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, humidity)
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/NH_Latitude_vs_ Humidity.png')
plt.show()
# Out:
# The r-value is: 0.15785253351179312

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
latitude = southern_hem['Lat']
humidity = southern_hem['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, humidity)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, humidity)
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/SH_Latitude_vs_ Humidity.png')
plt.show()
# Out:
# The r-value is: 0.01859004777664828

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
latitude = northern_hem['Lat']
cloudiness = northern_hem['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, cloudiness)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, cloudiness)
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(40,5),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/NH_Latitude_vs_ Cloudiness.png')
plt.show()
# Out:
# The r-value is: 0.036461629851412276

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
latitude = southern_hem['Lat']
cloudiness = southern_hem['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, cloudiness)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, cloudiness)
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(-55,25),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/SH_Latitude_vs_ Cloudiness.png')
plt.show()
# Out:
# The r-value is: 0.05070149212785231

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
latitude = northern_hem['Lat']
wind_speed = northern_hem['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, wind_speed)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, wind_speed)
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude")
plt.ylabel("Wind Speed(mph)")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(20,30),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/NH_Latitude_vs_ Wind.png')
plt.show()
# Out:
# The r-value is: 0.005957898240907351

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
latitude = southern_hem['Lat']
wind_speed = southern_hem['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, wind_speed)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, wind_speed)
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude")
plt.ylabel("Wind Speed(mph)")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/SH_Latitude_vs_ Wind.png')
plt.show()
# Out:
# The r-value is: 0.03795017096242096
