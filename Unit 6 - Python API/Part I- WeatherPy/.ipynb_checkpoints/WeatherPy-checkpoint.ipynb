# %% [markdown]
# # WeatherPy
# ----

# %% [markdown]
# ###   Analysis:

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

from pprint import pprint

# Import API key
weather_api_key = "4b0e3b0aab2982b37f2f4173ef8a6955"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 617

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?'
units = "metric"
lat = []
lng = []
max_temp =[]
humidity = []
cloud = []
wind_speed = []
country = []
date = []
city_name = []
x = 1

for city in cities:
    try:
        query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
        response = requests.get(query_url).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        city_name.append(response['name'])
        print(f"Processing Record {x} of {len(cities)} | {city}")
    except:
        print("City not found. Skipping....")
    x=x+1

print("--------------------------------")
print("Data Retrieval Complete")
print("--------------------------------")
# Out:
# Processing Record 1 of 617 | butaritari
# Processing Record 2 of 617 | albany
# Processing Record 3 of 617 | pizarro
# Processing Record 4 of 617 | mayumba
# Processing Record 5 of 617 | ostrovnoy
# City not found. Skipping....
# Processing Record 7 of 617 | bengkulu
# Processing Record 8 of 617 | jamestown
# City not found. Skipping....
# Processing Record 10 of 617 | truth or consequences
# Processing Record 11 of 617 | dikson
# Processing Record 12 of 617 | ribeira grande
# Processing Record 13 of 617 | bredasdorp
# Processing Record 14 of 617 | altay
# Processing Record 15 of 617 | llangefni
# Processing Record 16 of 617 | avarua
# Processing Record 17 of 617 | mataura
# Processing Record 18 of 617 | yala
# Processing Record 19 of 617 | jiamusi
# City not found. Skipping....
# Processing Record 21 of 617 | vad
# Processing Record 22 of 617 | hobart
# Processing Record 23 of 617 | yellowknife
# Processing Record 24 of 617 | katsuura
# Processing Record 25 of 617 | tuktoyaktuk
# Processing Record 26 of 617 | yar-sale
# Processing Record 27 of 617 | thompson
# Processing Record 28 of 617 | grants
# Processing Record 29 of 617 | cidreira
# Processing Record 30 of 617 | qaqortoq
# Processing Record 31 of 617 | cape town
# Processing Record 32 of 617 | sao filipe
# Processing Record 33 of 617 | mar del plata
# Processing Record 34 of 617 | maneadero
# City not found. Skipping....
# City not found. Skipping....
# Processing Record 37 of 617 | bluff
# Processing Record 38 of 617 | kapaa
# Processing Record 39 of 617 | vaini
# Processing Record 40 of 617 | rikitea
# Processing Record 41 of 617 | arlit
# Processing Record 42 of 617 | mana
# Processing Record 43 of 617 | busselton
# Processing Record 44 of 617 | pangnirtung
# City not found. Skipping....
# Processing Record 46 of 617 | georgetown
# Processing Record 47 of 617 | duvan
# Processing Record 48 of 617 | niquero
# Processing Record 49 of 617 | ushuaia
# Processing Record 50 of 617 | la ronge
# Processing Record 51 of 617 | andros
# Processing Record 52 of 617 | rawlins
# Processing Record 53 of 617 | kavieng
# Processing Record 54 of 617 | sorland
# Processing Record 55 of 617 | ahipara
# Processing Record 56 of 617 | puerto ayora
# Processing Record 57 of 617 | geraldton
# Processing Record 58 of 617 | athabasca
# Processing Record 59 of 617 | norman wells
# Processing Record 60 of 617 | dingle
# Processing Record 61 of 617 | saint-philippe
# Processing Record 62 of 617 | grindavik
# Processing Record 63 of 617 | bambous virieux
# Processing Record 64 of 617 | champerico
# Processing Record 65 of 617 | cervo
# Processing Record 66 of 617 | aguimes
# Processing Record 67 of 617 | poya
# Processing Record 68 of 617 | ponta do sol
# Processing Record 69 of 617 | lebu
# Processing Record 70 of 617 | airai
# Processing Record 71 of 617 | tasiilaq
# Processing Record 72 of 617 | havre-saint-pierre
# City not found. Skipping....
# Processing Record 74 of 617 | atuona
# City not found. Skipping....
# Processing Record 76 of 617 | saskylakh
# Processing Record 77 of 617 | qaanaaq
# Processing Record 78 of 617 | barrow
# Processing Record 79 of 617 | panticeu
# Processing Record 80 of 617 | husavik
# Processing Record 81 of 617 | rio gallegos
# Processing Record 82 of 617 | amahai
# Processing Record 83 of 617 | makakilo city
# Processing Record 84 of 617 | perleberg
# Processing Record 85 of 617 | te anau
# Processing Record 86 of 617 | tambacounda
# Processing Record 87 of 617 | beringovskiy
# Processing Record 88 of 617 | muyezerskiy
# Processing Record 89 of 617 | ilulissat
# Processing Record 90 of 617 | castro
# Processing Record 91 of 617 | havoysund
# Processing Record 92 of 617 | dondo
# Processing Record 93 of 617 | sakakah
# Processing Record 94 of 617 | punta arenas
# Processing Record 95 of 617 | fort nelson
# Processing Record 96 of 617 | severo-kurilsk
# Processing Record 97 of 617 | bethel
# Processing Record 98 of 617 | lavrentiya
# Processing Record 99 of 617 | saldanha
# Processing Record 100 of 617 | kamenka
# Processing Record 101 of 617 | bosaso
# Processing Record 102 of 617 | arraial do cabo
# Processing Record 103 of 617 | zhigansk
# Processing Record 104 of 617 | vila velha
# Processing Record 105 of 617 | ternate
# Processing Record 106 of 617 | khatanga
# Processing Record 107 of 617 | victor harbor
# Processing Record 108 of 617 | adrar
# Processing Record 109 of 617 | vao
# Processing Record 110 of 617 | college
# City not found. Skipping....
# Processing Record 112 of 617 | rock sound
# Processing Record 113 of 617 | pochutla
# City not found. Skipping....
# Processing Record 115 of 617 | daru
# Processing Record 116 of 617 | sitka
# Processing Record 117 of 617 | saint george
# Processing Record 118 of 617 | praia da vitoria
# Processing Record 119 of 617 | narsaq
# Processing Record 120 of 617 | moose factory
# Processing Record 121 of 617 | aripuana
# Processing Record 122 of 617 | monte alegre de minas
# Processing Record 123 of 617 | aklavik
# Processing Record 124 of 617 | richmond
# Processing Record 125 of 617 | naze
# Processing Record 126 of 617 | caucaia
# Processing Record 127 of 617 | upernavik
# Processing Record 128 of 617 | seoul
# Processing Record 129 of 617 | cotonou
# Processing Record 130 of 617 | nouna
# Processing Record 131 of 617 | turtas
# Processing Record 132 of 617 | nhulunbuy
# Processing Record 133 of 617 | katangli
# Processing Record 134 of 617 | hilo
# Processing Record 135 of 617 | salinas
# Processing Record 136 of 617 | dovolnoye
# Processing Record 137 of 617 | tatishchevo
# Processing Record 138 of 617 | port alfred
# Processing Record 139 of 617 | qeshm
# Processing Record 140 of 617 | araouane
# Processing Record 141 of 617 | constitucion
# Processing Record 142 of 617 | bindi
# Processing Record 143 of 617 | kars
# Processing Record 144 of 617 | lishu
# Processing Record 145 of 617 | lagos
# City not found. Skipping....
# Processing Record 147 of 617 | necochea
# Processing Record 148 of 617 | hailey
# Processing Record 149 of 617 | faanui
# Processing Record 150 of 617 | goderich
# Processing Record 151 of 617 | tukrah
# Processing Record 152 of 617 | peterhead
# Processing Record 153 of 617 | new norfolk
# Processing Record 154 of 617 | ormara
# Processing Record 155 of 617 | east london
# Processing Record 156 of 617 | kodiak
# Processing Record 157 of 617 | sao felix do xingu
# Processing Record 158 of 617 | bang saphan
# Processing Record 159 of 617 | hirara
# City not found. Skipping....
# Processing Record 161 of 617 | pella
# Processing Record 162 of 617 | lompoc
# City not found. Skipping....
# City not found. Skipping....
# Processing Record 165 of 617 | sharjah
# Processing Record 166 of 617 | kahului
# Processing Record 167 of 617 | margate
# Processing Record 168 of 617 | clyde river
# City not found. Skipping....
# Processing Record 170 of 617 | carnarvon
# Processing Record 171 of 617 | corralillo
# Processing Record 172 of 617 | hermanus
# Processing Record 173 of 617 | kiruna
# Processing Record 174 of 617 | beloha
# Processing Record 175 of 617 | matagami
# City not found. Skipping....
# Processing Record 177 of 617 | kruisfontein
# Processing Record 178 of 617 | hammerfest
# Processing Record 179 of 617 | omboue
# City not found. Skipping....
# Processing Record 181 of 617 | krasnodon
# City not found. Skipping....
# Processing Record 183 of 617 | okakarara
# Processing Record 184 of 617 | port lincoln
# Processing Record 185 of 617 | tuatapere
# Processing Record 186 of 617 | kroya
# Processing Record 187 of 617 | henties bay
# Processing Record 188 of 617 | sanmenxia
# Processing Record 189 of 617 | victoria
# City not found. Skipping....
# Processing Record 191 of 617 | port moresby
# Processing Record 192 of 617 | manitowoc
# Processing Record 193 of 617 | provideniya
# Processing Record 194 of 617 | luderitz
# Processing Record 195 of 617 | rocky mountain house
# Processing Record 196 of 617 | aksarka
# Processing Record 197 of 617 | portland
# Processing Record 198 of 617 | prince rupert
# Processing Record 199 of 617 | hearst
# Processing Record 200 of 617 | gazojak
# Processing Record 201 of 617 | sanming
# City not found. Skipping....
# Processing Record 203 of 617 | pemangkat
# Processing Record 204 of 617 | curup
# Processing Record 205 of 617 | zhumadian
# City not found. Skipping....
# Processing Record 207 of 617 | uba
# Processing Record 208 of 617 | isangel
# Processing Record 209 of 617 | acapulco
# Processing Record 210 of 617 | bundaberg
# City not found. Skipping....
# Processing Record 212 of 617 | spornoye
# Processing Record 213 of 617 | broome
# Processing Record 214 of 617 | zhangjiakou
# Processing Record 215 of 617 | abalak
# Processing Record 216 of 617 | fortuna
# Processing Record 217 of 617 | ourossogui
# Processing Record 218 of 617 | cockburn town
# Processing Record 219 of 617 | lufilufi
# Processing Record 220 of 617 | tiksi
# Processing Record 221 of 617 | paracuru
# Processing Record 222 of 617 | port elizabeth
# Processing Record 223 of 617 | codrington
# Processing Record 224 of 617 | ewo
# Processing Record 225 of 617 | korla
# Processing Record 226 of 617 | palmerston
# Processing Record 227 of 617 | touros
# Processing Record 228 of 617 | tautira
# Processing Record 229 of 617 | kaitangata
# Processing Record 230 of 617 | san cristobal
# Processing Record 231 of 617 | esperance
# Processing Record 232 of 617 | compostela
# City not found. Skipping....
# Processing Record 234 of 617 | aswan
# Processing Record 235 of 617 | fairbanks
# Processing Record 236 of 617 | souillac
# Processing Record 237 of 617 | koumac
# Processing Record 238 of 617 | klaksvik
# Processing Record 239 of 617 | huanren
# Processing Record 240 of 617 | road town
# Processing Record 241 of 617 | sabang
# Processing Record 242 of 617 | oudtshoorn
# Processing Record 243 of 617 | pevek
# Processing Record 244 of 617 | shahr-e babak
# Processing Record 245 of 617 | hithadhoo
# Processing Record 246 of 617 | bom despacho
# Processing Record 247 of 617 | sainte-thecle
# Processing Record 248 of 617 | torbay
# Processing Record 249 of 617 | bara
# Processing Record 250 of 617 | cherskiy
# Processing Record 251 of 617 | whyalla
# Processing Record 252 of 617 | mahebourg
# Processing Record 253 of 617 | siniscola
# Processing Record 254 of 617 | mastic beach
# Processing Record 255 of 617 | vrutky
# Processing Record 256 of 617 | roma
# Processing Record 257 of 617 | oranjestad
# Processing Record 258 of 617 | chuy
# Processing Record 259 of 617 | nikolskoye
# Processing Record 260 of 617 | tura
# Processing Record 261 of 617 | namatanai
# Processing Record 262 of 617 | guarda
# Processing Record 263 of 617 | mikhaylovka
# Processing Record 264 of 617 | westport
# Processing Record 265 of 617 | sao joao da barra
# City not found. Skipping....
# Processing Record 267 of 617 | trinidad
# Processing Record 268 of 617 | caravelas
# Processing Record 269 of 617 | paamiut
# Processing Record 270 of 617 | newport
# Processing Record 271 of 617 | koulamoutou
# City not found. Skipping....
# Processing Record 273 of 617 | banda aceh
# Processing Record 274 of 617 | kiama
# Processing Record 275 of 617 | haines junction
# Processing Record 276 of 617 | guerrero negro
# Processing Record 277 of 617 | takoradi
# Processing Record 278 of 617 | lukovetskiy
# Processing Record 279 of 617 | burns lake
# Processing Record 280 of 617 | jalu
# Processing Record 281 of 617 | boddam
# Processing Record 282 of 617 | singaraja
# Processing Record 283 of 617 | port hardy
# Processing Record 284 of 617 | ballina
# Processing Record 285 of 617 | kargasok
# Processing Record 286 of 617 | snasa
# City not found. Skipping....
# Processing Record 288 of 617 | nanortalik
# Processing Record 289 of 617 | iqaluit
# Processing Record 290 of 617 | janoshaza
# City not found. Skipping....
# Processing Record 292 of 617 | lorengau
# Processing Record 293 of 617 | hasaki
# Processing Record 294 of 617 | bilma
# Processing Record 295 of 617 | ponta grossa
# Processing Record 296 of 617 | lagoa
# City not found. Skipping....
# Processing Record 298 of 617 | kahramanmaras
# Processing Record 299 of 617 | port-gentil
# Processing Record 300 of 617 | hambantota
# Processing Record 301 of 617 | inhambane
# Processing Record 302 of 617 | kingaroy
# Processing Record 303 of 617 | slobodskoy
# Processing Record 304 of 617 | sibolga
# Processing Record 305 of 617 | faya
# Processing Record 306 of 617 | paka
# Processing Record 307 of 617 | yongan
# Processing Record 308 of 617 | talnakh
# City not found. Skipping....
# Processing Record 310 of 617 | khani
# City not found. Skipping....
# Processing Record 312 of 617 | do gonbadan
# City not found. Skipping....
# Processing Record 314 of 617 | estacion coahuila
# Processing Record 315 of 617 | chifeng
# Processing Record 316 of 617 | lata
# Processing Record 317 of 617 | okhotsk
# Processing Record 318 of 617 | bucerias
# Processing Record 319 of 617 | tilichiki
# Processing Record 320 of 617 | conde
# Processing Record 321 of 617 | saint-augustin
# Processing Record 322 of 617 | launceston
# Processing Record 323 of 617 | turbat
# Processing Record 324 of 617 | gushikawa
# Processing Record 325 of 617 | port hedland
# Processing Record 326 of 617 | aginskoye
# Processing Record 327 of 617 | san andres
# Processing Record 328 of 617 | coyah
# Processing Record 329 of 617 | chiredzi
# Processing Record 330 of 617 | santa rosa
# Processing Record 331 of 617 | voh
# Processing Record 332 of 617 | olinda
# Processing Record 333 of 617 | lethem
# Processing Record 334 of 617 | maceio
# Processing Record 335 of 617 | seminole
# Processing Record 336 of 617 | bataipora
# Processing Record 337 of 617 | alice springs
# Processing Record 338 of 617 | annamalainagar
# Processing Record 339 of 617 | jipijapa
# Processing Record 340 of 617 | rabak
# City not found. Skipping....
# Processing Record 342 of 617 | pingliang
# Processing Record 343 of 617 | deputatskiy
# Processing Record 344 of 617 | leh
# Processing Record 345 of 617 | hami
# Processing Record 346 of 617 | mangalia
# Processing Record 347 of 617 | acajutla
# Processing Record 348 of 617 | ust-ishim
# Processing Record 349 of 617 | bassano
# Processing Record 350 of 617 | shinjo
# Processing Record 351 of 617 | shaunavon
# Processing Record 352 of 617 | mehamn
# Processing Record 353 of 617 | anloga
# Processing Record 354 of 617 | sayyan
# Processing Record 355 of 617 | san felipe
# Processing Record 356 of 617 | key largo
# Processing Record 357 of 617 | baker city
# Processing Record 358 of 617 | balvi
# Processing Record 359 of 617 | kedrovyy
# Processing Record 360 of 617 | laguna
# Processing Record 361 of 617 | namibe
# Processing Record 362 of 617 | port macquarie
# Processing Record 363 of 617 | manzhouli
# Processing Record 364 of 617 | caborca
# Processing Record 365 of 617 | masvingo
# Processing Record 366 of 617 | ciudad bolivar
# Processing Record 367 of 617 | diffa
# Processing Record 368 of 617 | coihaique
# Processing Record 369 of 617 | nacozari
# Processing Record 370 of 617 | sambava
# Processing Record 371 of 617 | aktash
# Processing Record 372 of 617 | saint-leu
# Processing Record 373 of 617 | taltal
# Processing Record 374 of 617 | paidha
# Processing Record 375 of 617 | san ramon
# Processing Record 376 of 617 | kulhudhuffushi
# City not found. Skipping....
# Processing Record 378 of 617 | thaba-tseka
# Processing Record 379 of 617 | buckeye
# Processing Record 380 of 617 | bismil
# Processing Record 381 of 617 | zabaykalsk
# Processing Record 382 of 617 | apollonia
# Processing Record 383 of 617 | alofi
# Processing Record 384 of 617 | los llanos de aridane
# Processing Record 385 of 617 | tikamgarh
# Processing Record 386 of 617 | labuhan
# Processing Record 387 of 617 | poronaysk
# Processing Record 388 of 617 | havelock
# Processing Record 389 of 617 | nagapattinam
# City not found. Skipping....
# Processing Record 391 of 617 | kununurra
# Processing Record 392 of 617 | mareeba
# City not found. Skipping....
# Processing Record 394 of 617 | america dourada
# City not found. Skipping....
# Processing Record 396 of 617 | san quintin
# Processing Record 397 of 617 | archidona
# Processing Record 398 of 617 | sidmouth
# Processing Record 399 of 617 | vysokogornyy
# Processing Record 400 of 617 | palmer
# Processing Record 401 of 617 | jambi
# Processing Record 402 of 617 | tanggu
# Processing Record 403 of 617 | youkounkoun
# Processing Record 404 of 617 | ponta delgada
# Processing Record 405 of 617 | cayenne
# Processing Record 406 of 617 | kirakira
# Processing Record 407 of 617 | karratha
# Processing Record 408 of 617 | coolum beach
# Processing Record 409 of 617 | anisoc
# Processing Record 410 of 617 | manokwari
# Processing Record 411 of 617 | meulaboh
# Processing Record 412 of 617 | marsh harbour
# Processing Record 413 of 617 | san patricio
# Processing Record 414 of 617 | buston
# Processing Record 415 of 617 | seredka
# Processing Record 416 of 617 | mama
# Processing Record 417 of 617 | coquimbo
# Processing Record 418 of 617 | banjar
# Processing Record 419 of 617 | asau
# Processing Record 420 of 617 | aloleng
# Processing Record 421 of 617 | vanimo
# Processing Record 422 of 617 | san carlos de bariloche
# Processing Record 423 of 617 | alugan
# Processing Record 424 of 617 | sisophon
# Processing Record 425 of 617 | hargeysa
# Processing Record 426 of 617 | rawson
# Processing Record 427 of 617 | dunedin
# Processing Record 428 of 617 | khorramshahr
# Processing Record 429 of 617 | fare
# Processing Record 430 of 617 | stillwater
# Processing Record 431 of 617 | antalaha
# Processing Record 432 of 617 | ashington
# Processing Record 433 of 617 | hualmay
# Processing Record 434 of 617 | chokurdakh
# Processing Record 435 of 617 | seryshevo
# Processing Record 436 of 617 | bandiagara
# Processing Record 437 of 617 | leningradskiy
# Processing Record 438 of 617 | zarubino
# Processing Record 439 of 617 | butembo
# Processing Record 440 of 617 | carballo
# Processing Record 441 of 617 | taoudenni
# City not found. Skipping....
# Processing Record 443 of 617 | saint-joseph
# Processing Record 444 of 617 | turukhansk
# Processing Record 445 of 617 | alenquer
# Processing Record 446 of 617 | dongsheng
# Processing Record 447 of 617 | southbridge
# Processing Record 448 of 617 | khalkhal
# Processing Record 449 of 617 | san jose
# Processing Record 450 of 617 | albanel
# Processing Record 451 of 617 | bodden town
# Processing Record 452 of 617 | waterloo
# Processing Record 453 of 617 | zhob
# Processing Record 454 of 617 | placido de castro
# Processing Record 455 of 617 | kodinsk
# Processing Record 456 of 617 | usogorsk
# Processing Record 457 of 617 | bo phloi
# City not found. Skipping....
# Processing Record 459 of 617 | nadvoitsy
# Processing Record 460 of 617 | mahibadhoo
# Processing Record 461 of 617 | santarem
# Processing Record 462 of 617 | ancud
# Processing Record 463 of 617 | chongwe
# City not found. Skipping....
# Processing Record 465 of 617 | nishihara
# City not found. Skipping....
# Processing Record 467 of 617 | digby
# Processing Record 468 of 617 | kavaratti
# Processing Record 469 of 617 | cruzeiro do sul
# Processing Record 470 of 617 | salalah
# Processing Record 471 of 617 | fernandez
# Processing Record 472 of 617 | poum
# Processing Record 473 of 617 | port-cartier
# Processing Record 474 of 617 | san policarpo
# Processing Record 475 of 617 | kyren
# City not found. Skipping....
# Processing Record 477 of 617 | bontang
# Processing Record 478 of 617 | williams lake
# Processing Record 479 of 617 | harper
# Processing Record 480 of 617 | samarai
# City not found. Skipping....
# Processing Record 482 of 617 | xiuyan
# Processing Record 483 of 617 | ishigaki
# Processing Record 484 of 617 | talcahuano
# Processing Record 485 of 617 | ugoofaaru
# Processing Record 486 of 617 | petropavlovsk-kamchatskiy
# Processing Record 487 of 617 | salvador
# Processing Record 488 of 617 | richards bay
# Processing Record 489 of 617 | pandan
# Processing Record 490 of 617 | ossora
# Processing Record 491 of 617 | cachoeiras de macacu
# Processing Record 492 of 617 | nizwa
# Processing Record 493 of 617 | nuuk
# Processing Record 494 of 617 | rio grande
# Processing Record 495 of 617 | chikmagalur
# Processing Record 496 of 617 | marystown
# Processing Record 497 of 617 | quatre cocos
# Processing Record 498 of 617 | malakal
# Processing Record 499 of 617 | xuddur
# Processing Record 500 of 617 | romans-sur-isere
# Processing Record 501 of 617 | sunland park
# Processing Record 502 of 617 | padang
# Processing Record 503 of 617 | amurzet
# Processing Record 504 of 617 | gummidipundi
# Processing Record 505 of 617 | qasigiannguit
# Processing Record 506 of 617 | patti
# Processing Record 507 of 617 | sioux lookout
# Processing Record 508 of 617 | greenville
# Processing Record 509 of 617 | yajalon
# City not found. Skipping....
# Processing Record 511 of 617 | arica
# Processing Record 512 of 617 | sisimiut
# Processing Record 513 of 617 | nome
# Processing Record 514 of 617 | port augusta
# City not found. Skipping....
# Processing Record 516 of 617 | berlevag
# Processing Record 517 of 617 | hazorasp
# Processing Record 518 of 617 | san jeronimo
# Processing Record 519 of 617 | okha
# Processing Record 520 of 617 | kapoeta
# Processing Record 521 of 617 | am timan
# Processing Record 522 of 617 | pisco
# Processing Record 523 of 617 | chinsali
# Processing Record 524 of 617 | cassilandia
# Processing Record 525 of 617 | baykit
# City not found. Skipping....
# Processing Record 527 of 617 | basco
# Processing Record 528 of 617 | san cayetano
# Processing Record 529 of 617 | sosnovo
# Processing Record 530 of 617 | villamontes
# Processing Record 531 of 617 | atbasar
# Processing Record 532 of 617 | manaure
# Processing Record 533 of 617 | sur
# Processing Record 534 of 617 | jumla
# Processing Record 535 of 617 | queimadas
# Processing Record 536 of 617 | saquarema
# Processing Record 537 of 617 | tomatlan
# Processing Record 538 of 617 | kieta
# Processing Record 539 of 617 | wamba
# Processing Record 540 of 617 | yumen
# Processing Record 541 of 617 | srivardhan
# Processing Record 542 of 617 | kemijarvi
# Processing Record 543 of 617 | sajanan
# Processing Record 544 of 617 | fauske
# Processing Record 545 of 617 | tottori
# Processing Record 546 of 617 | pokhvistnevo
# Processing Record 547 of 617 | itarema
# Processing Record 548 of 617 | tripoli
# Processing Record 549 of 617 | kichmengskiy gorodok
# Processing Record 550 of 617 | kautokeino
# Processing Record 551 of 617 | akkermanovka
# Processing Record 552 of 617 | bilibino
# Processing Record 553 of 617 | maues
# City not found. Skipping....
# Processing Record 555 of 617 | bantry
# Processing Record 556 of 617 | lalmohan
# Processing Record 557 of 617 | palmas
# Processing Record 558 of 617 | chiclayo
# Processing Record 559 of 617 | naryan-mar
# Processing Record 560 of 617 | rojhan
# Processing Record 561 of 617 | bowling green
# Processing Record 562 of 617 | krasnoselkup
# Processing Record 563 of 617 | yerbogachen
# Processing Record 564 of 617 | peniche
# Processing Record 565 of 617 | sinnamary
# Processing Record 566 of 617 | olafsvik
# Processing Record 567 of 617 | cabo san lucas
# Processing Record 568 of 617 | trapani
# Processing Record 569 of 617 | praia
# Processing Record 570 of 617 | kaeo
# Processing Record 571 of 617 | carmen
# Processing Record 572 of 617 | puerto madryn
# Processing Record 573 of 617 | shingu
# Processing Record 574 of 617 | vagur
# Processing Record 575 of 617 | vila franca do campo
# Processing Record 576 of 617 | virginia beach
# Processing Record 577 of 617 | ixtapa
# Processing Record 578 of 617 | tigil
# Processing Record 579 of 617 | madang
# Processing Record 580 of 617 | guaraniacu
# Processing Record 581 of 617 | maragogi
# Processing Record 582 of 617 | bathsheba
# Processing Record 583 of 617 | mount gambier
# Processing Record 584 of 617 | mackay
# Processing Record 585 of 617 | san vicente
# Processing Record 586 of 617 | alta floresta
# Processing Record 587 of 617 | mazamari
# Processing Record 588 of 617 | rock falls
# City not found. Skipping....
# Processing Record 590 of 617 | gat
# Processing Record 591 of 617 | maoming
# Processing Record 592 of 617 | astoria
# Processing Record 593 of 617 | gorontalo
# City not found. Skipping....
# Processing Record 595 of 617 | morehead
# Processing Record 596 of 617 | raudeberg
# City not found. Skipping....
# Processing Record 598 of 617 | quang ngai
# Processing Record 599 of 617 | kota kinabalu
# Processing Record 600 of 617 | hamilton
# Processing Record 601 of 617 | calabozo
# Processing Record 602 of 617 | san miguelito
# Processing Record 603 of 617 | baghdad
# Processing Record 604 of 617 | lalawigan
# City not found. Skipping....
# Processing Record 606 of 617 | poltavka
# Processing Record 607 of 617 | copiapo
# Processing Record 608 of 617 | pyay
# City not found. Skipping....
# Processing Record 610 of 617 | stirling
# City not found. Skipping....
# Processing Record 612 of 617 | porto novo
# Processing Record 613 of 617 | armidale
# Processing Record 614 of 617 | marzuq
# Processing Record 615 of 617 | yantzaza
# Processing Record 616 of 617 | taos
# Processing Record 617 of 617 | rzeszow
# --------------------------------
# Data Retrieval Complete
# --------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({"City": city_name, "Lat":lat, "Lng":lng,"Max Temp": max_temp, 
                           "Humidity":humidity, "Cloudiness": cloud, "Wind Speed": wind_speed, 
                          "Country":country, "Date": date})
weather_df.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Butaritari   3.07  172.79     27.59        78          97        7.63
# 1      Albany  42.60  -73.97      1.11        88         100        3.25
# 2     Pizarro   4.95  -77.37     27.77        73          18        3.28
# 3     Mayumba  -3.43   10.66     25.13        90          95        4.25
# 4   Ostrovnoy  68.05   39.51      1.35        89          63        8.93
#
#   Country        Date
# 0      KI  1604072907
# 1      US  1604072813
# 2      CO  1604073104
# 3      GA  1604073104
# 4      RU  1604072885

# %%
weather_df.to_csv('output.csv', index = False)

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  565.000000  565.000000  565.000000  565.000000  565.000000  565.000000
# mean    19.663628   15.223345   15.591381   71.787611   53.021239    3.712584
# std     32.952300   91.522207   12.812438   20.664344   38.149569    2.712170
# min    -54.800000 -175.200000  -24.490000    1.000000    0.000000    0.150000
# 25%     -7.630000  -66.870000    5.290000   63.000000   13.000000    1.750000
# 50%     22.340000   18.920000   19.440000   76.000000   60.000000    3.100000
# 75%     47.870000   99.180000   26.000000   88.000000   90.000000    5.010000
# max     77.480000  179.320000   42.000000  100.000000  100.000000   15.090000
#
#                Date
# count  5.650000e+02
# mean   1.604073e+09
# std    8.314220e+01
# min    1.604073e+09
# 25%    1.604073e+09
# 50%    1.604073e+09
# 75%    1.604073e+09
# max    1.604073e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
latitude = weather_df['Lat']
temperature = weather_df['Max Temp']

plt.scatter(latitude, temperature, edgecolor = "black")
plt.title("City Latitude vs. Max Temperature (30/10/20)")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
latitude = weather_df['Lat']
humidity = weather_df['Humidity']

plt.scatter(latitude, humidity, facecolor = 'red',edgecolor = "black")
plt.title("City Latitude vs. Humidity (30/10/20)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
latitude = weather_df['Lat']
cloudiness = weather_df['Cloudiness']

plt.scatter(latitude, cloudiness, facecolor = 'green',edgecolor = "black")
plt.title("City Latitude vs. Cloudiness (30/10/20)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
latitude = weather_df['Lat']
wind_speed = weather_df['Wind Speed']

plt.scatter(latitude, wind_speed, facecolor = 'orange',edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (30/10/20)")
plt.ylabel("Wind Speed (kmph)")
plt.xlabel("Latitude")
plt.grid()
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
northern_hem = weather_df.loc[weather_df['Lat']>0]
southern_hem = weather_df.loc[weather_df['Lat']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
latitude = northern_hem['Lat']
temperature = northern_hem['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, temperature)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, temperature)
plt.title("Northern Hemisphere - Max Temp vs. Latitude")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(15,-20),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.7751713069617315

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
latitude = southern_hem['Lat']
temperature = southern_hem['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, temperature)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, temperature)
plt.title("Southern Hemisphere - Max Temp vs. Latitude")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(-50,35),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.586675561308636

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
latitude = northern_hem['Lat']
humidity = northern_hem['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, humidity)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, humidity)
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.1264136167524528

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
latitude = southern_hem['Lat']
humidity = southern_hem['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, humidity)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, humidity)
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.01610573024630914

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
latitude = northern_hem['Lat']
cloudiness = northern_hem['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, cloudiness)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, cloudiness)
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(40,5),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.04798085945638878

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
latitude = southern_hem['Lat']
cloudiness = southern_hem['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, cloudiness)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, cloudiness)
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(-55,25),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.04380913952081828

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (kmph) vs. Latitude Linear Regression

# %%
latitude = northern_hem['Lat']
wind_speed = northern_hem['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, wind_speed)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, wind_speed)
plt.title("Northern Hemisphere - Wind Speed (kmph) vs. Latitude")
plt.ylabel("Wind Speed(kmph)")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(20,12),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.0055322924018279636

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (kmph) vs. Latitude Linear Regression

# %%
latitude = southern_hem['Lat']
wind_speed = southern_hem['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, wind_speed)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, wind_speed)
plt.title("Southern Hemisphere - Wind Speed (kmph) vs. Latitude")
plt.ylabel("Wind Speed(kmph)")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(-50,8),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.04626340096820391
