# %% [markdown]
# # WeatherPy
# ----

# %% [markdown]
# ###   Analysis:
#
# * As cities approach the equator (Latitude = 0), they have a higher maximum temperature.
# * There is not a strong correlation between latitude and either humidity, cloudiness, or windspeed.
# * In the northern hemisphere on the date that the data was pulled (Oct 30, 2020) there is a high proportion of cities with humidity of greater than 60%.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

from pprint import pprint

# Import API key
weather_api_key = "4b0e3b0aab2982b37f2f4173ef8a6955"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 645

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?'
units = "imperial"
lat = []
lng = []
max_temp =[]
humidity = []
cloud = []
wind_speed = []
country = []
date = []
city_name = []
x = 1

for city in cities:
    try:
        query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
        response = requests.get(query_url).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        city_name.append(response['name'])
        print(f"Processing Record {x} of {len(cities)} | {city}")
    except:
        print("City not found. Skipping....")
    x=x+1

print("--------------------------------")
print("Data Retrieval Complete")
print("--------------------------------")
# Out:
# Processing Record 1 of 645 | placido de castro
# Processing Record 2 of 645 | mataura
# Processing Record 3 of 645 | isangel
# Processing Record 4 of 645 | saquarema
# Processing Record 5 of 645 | haines junction
# Processing Record 6 of 645 | cape town
# Processing Record 7 of 645 | niteroi
# Processing Record 8 of 645 | provideniya
# Processing Record 9 of 645 | salina cruz
# Processing Record 10 of 645 | pochutla
# City not found. Skipping....
# City not found. Skipping....
# Processing Record 13 of 645 | constitucion
# Processing Record 14 of 645 | butaritari
# Processing Record 15 of 645 | castro
# Processing Record 16 of 645 | salinopolis
# Processing Record 17 of 645 | albany
# Processing Record 18 of 645 | ribeira grande
# Processing Record 19 of 645 | mar del plata
# Processing Record 20 of 645 | hermanus
# Processing Record 21 of 645 | yurimaguas
# Processing Record 22 of 645 | bluff
# Processing Record 23 of 645 | wonthaggi
# Processing Record 24 of 645 | hilo
# Processing Record 25 of 645 | killam
# Processing Record 26 of 645 | adwa
# Processing Record 27 of 645 | bethel
# Processing Record 28 of 645 | hithadhoo
# Processing Record 29 of 645 | hobart
# Processing Record 30 of 645 | ayr
# Processing Record 31 of 645 | pompeia
# Processing Record 32 of 645 | puerto ayora
# Processing Record 33 of 645 | atuona
# Processing Record 34 of 645 | margate
# Processing Record 35 of 645 | asyut
# Processing Record 36 of 645 | ambon
# Processing Record 37 of 645 | guhagar
# Processing Record 38 of 645 | torbay
# Processing Record 39 of 645 | tiksi
# Processing Record 40 of 645 | moche
# Processing Record 41 of 645 | cherskiy
# Processing Record 42 of 645 | shitanjing
# Processing Record 43 of 645 | barrow
# Processing Record 44 of 645 | bredasdorp
# Processing Record 45 of 645 | marabba
# Processing Record 46 of 645 | deloraine
# City not found. Skipping....
# Processing Record 48 of 645 | punta arenas
# Processing Record 49 of 645 | vardo
# Processing Record 50 of 645 | ushuaia
# Processing Record 51 of 645 | rikitea
# Processing Record 52 of 645 | port hardy
# City not found. Skipping....
# Processing Record 54 of 645 | georgetown
# Processing Record 55 of 645 | dikson
# Processing Record 56 of 645 | new norfolk
# City not found. Skipping....
# City not found. Skipping....
# Processing Record 59 of 645 | sao filipe
# Processing Record 60 of 645 | jensen beach
# Processing Record 61 of 645 | dingle
# Processing Record 62 of 645 | saldanha
# Processing Record 63 of 645 | tuktoyaktuk
# Processing Record 64 of 645 | upernavik
# Processing Record 65 of 645 | hambantota
# Processing Record 66 of 645 | namtsy
# City not found. Skipping....
# Processing Record 68 of 645 | east london
# Processing Record 69 of 645 | jamestown
# Processing Record 70 of 645 | ilulissat
# Processing Record 71 of 645 | san patricio
# Processing Record 72 of 645 | corrente
# Processing Record 73 of 645 | bagdarin
# Processing Record 74 of 645 | thompson
# Processing Record 75 of 645 | zavodouspenskoye
# Processing Record 76 of 645 | avarua
# City not found. Skipping....
# Processing Record 78 of 645 | magole
# Processing Record 79 of 645 | lompoc
# Processing Record 80 of 645 | port alfred
# Processing Record 81 of 645 | chuy
# Processing Record 82 of 645 | toamasina
# Processing Record 83 of 645 | saskylakh
# Processing Record 84 of 645 | beruwala
# Processing Record 85 of 645 | tautira
# Processing Record 86 of 645 | raudeberg
# Processing Record 87 of 645 | klembivka
# Processing Record 88 of 645 | lorengau
# Processing Record 89 of 645 | lypnyazhka
# Processing Record 90 of 645 | tayshet
# Processing Record 91 of 645 | airai
# Processing Record 92 of 645 | lavrentiya
# Processing Record 93 of 645 | severo-kurilsk
# Processing Record 94 of 645 | casablanca
# Processing Record 95 of 645 | port keats
# Processing Record 96 of 645 | eyl
# City not found. Skipping....
# Processing Record 98 of 645 | bengkulu
# Processing Record 99 of 645 | santa maria
# Processing Record 100 of 645 | yemelyanovo
# City not found. Skipping....
# Processing Record 102 of 645 | lodwar
# Processing Record 103 of 645 | kutahya
# Processing Record 104 of 645 | lima
# Processing Record 105 of 645 | buala
# Processing Record 106 of 645 | kapaa
# Processing Record 107 of 645 | pailon
# City not found. Skipping....
# Processing Record 109 of 645 | vila velha
# Processing Record 110 of 645 | saint-philippe
# Processing Record 111 of 645 | fortuna
# City not found. Skipping....
# Processing Record 113 of 645 | kambia
# Processing Record 114 of 645 | yuncheng
# Processing Record 115 of 645 | bambous virieux
# Processing Record 116 of 645 | lekoni
# Processing Record 117 of 645 | uto
# Processing Record 118 of 645 | nyurba
# Processing Record 119 of 645 | maple creek
# Processing Record 120 of 645 | okhansk
# Processing Record 121 of 645 | naze
# Processing Record 122 of 645 | fredericton
# Processing Record 123 of 645 | quelimane
# Processing Record 124 of 645 | colares
# Processing Record 125 of 645 | kutum
# Processing Record 126 of 645 | bac lieu
# Processing Record 127 of 645 | tasiilaq
# Processing Record 128 of 645 | fiumicino
# Processing Record 129 of 645 | praia da vitoria
# Processing Record 130 of 645 | hay river
# Processing Record 131 of 645 | perth
# City not found. Skipping....
# Processing Record 133 of 645 | marawi
# Processing Record 134 of 645 | salo
# Processing Record 135 of 645 | antofagasta
# Processing Record 136 of 645 | jaque
# Processing Record 137 of 645 | hirara
# Processing Record 138 of 645 | darhan
# Processing Record 139 of 645 | zhigansk
# Processing Record 140 of 645 | kodiak
# Processing Record 141 of 645 | esperance
# Processing Record 142 of 645 | rumphi
# City not found. Skipping....
# Processing Record 144 of 645 | letlhakeng
# Processing Record 145 of 645 | chokurdakh
# Processing Record 146 of 645 | paulo ramos
# Processing Record 147 of 645 | tsabong
# City not found. Skipping....
# Processing Record 149 of 645 | zhongshu
# Processing Record 150 of 645 | guerrero negro
# Processing Record 151 of 645 | ust-kut
# City not found. Skipping....
# Processing Record 153 of 645 | nueva gorgona
# Processing Record 154 of 645 | itaituba
# Processing Record 155 of 645 | vengerovo
# Processing Record 156 of 645 | codrington
# Processing Record 157 of 645 | road town
# Processing Record 158 of 645 | laramie
# Processing Record 159 of 645 | lagoa
# Processing Record 160 of 645 | axim
# Processing Record 161 of 645 | xiongyue
# Processing Record 162 of 645 | nador
# Processing Record 163 of 645 | srednekolymsk
# Processing Record 164 of 645 | mahibadhoo
# Processing Record 165 of 645 | lebu
# City not found. Skipping....
# Processing Record 167 of 645 | acarau
# Processing Record 168 of 645 | vaini
# Processing Record 169 of 645 | sepuka
# Processing Record 170 of 645 | kavieng
# Processing Record 171 of 645 | luena
# Processing Record 172 of 645 | cockburn town
# Processing Record 173 of 645 | nanortalik
# Processing Record 174 of 645 | yellowknife
# Processing Record 175 of 645 | jiayuguan
# Processing Record 176 of 645 | marzuq
# Processing Record 177 of 645 | morro bay
# Processing Record 178 of 645 | narsaq
# Processing Record 179 of 645 | banda aceh
# Processing Record 180 of 645 | lisieux
# Processing Record 181 of 645 | mahebourg
# City not found. Skipping....
# Processing Record 183 of 645 | katsuura
# Processing Record 184 of 645 | qaanaaq
# Processing Record 185 of 645 | faanui
# Processing Record 186 of 645 | hasaki
# Processing Record 187 of 645 | qasigiannguit
# Processing Record 188 of 645 | carnarvon
# Processing Record 189 of 645 | coquimbo
# Processing Record 190 of 645 | launceston
# Processing Record 191 of 645 | poum
# Processing Record 192 of 645 | luanda
# Processing Record 193 of 645 | busselton
# Processing Record 194 of 645 | udayagiri
# Processing Record 195 of 645 | petropavlovsk-kamchatskiy
# Processing Record 196 of 645 | thio
# Processing Record 197 of 645 | kamra
# Processing Record 198 of 645 | umea
# Processing Record 199 of 645 | trondheim
# Processing Record 200 of 645 | amga
# Processing Record 201 of 645 | palera
# Processing Record 202 of 645 | mayo
# Processing Record 203 of 645 | hlotse
# Processing Record 204 of 645 | olafsvik
# Processing Record 205 of 645 | tutoia
# Processing Record 206 of 645 | saint-georges
# Processing Record 207 of 645 | aktash
# Processing Record 208 of 645 | makakilo city
# Processing Record 209 of 645 | moose factory
# Processing Record 210 of 645 | naron
# Processing Record 211 of 645 | bull savanna
# Processing Record 212 of 645 | te anau
# Processing Record 213 of 645 | bathsheba
# Processing Record 214 of 645 | honningsvag
# Processing Record 215 of 645 | kashi
# Processing Record 216 of 645 | port lincoln
# Processing Record 217 of 645 | asau
# Processing Record 218 of 645 | nikolskoye
# Processing Record 219 of 645 | krasnyy yar
# Processing Record 220 of 645 | la baneza
# Processing Record 221 of 645 | talnakh
# City not found. Skipping....
# City not found. Skipping....
# Processing Record 224 of 645 | arlit
# Processing Record 225 of 645 | husavik
# City not found. Skipping....
# Processing Record 227 of 645 | mbandaka
# Processing Record 228 of 645 | barmer
# Processing Record 229 of 645 | clyde river
# Processing Record 230 of 645 | liverpool
# Processing Record 231 of 645 | aklavik
# Processing Record 232 of 645 | segezha
# Processing Record 233 of 645 | aksu
# Processing Record 234 of 645 | podgorenskiy
# Processing Record 235 of 645 | pangnirtung
# Processing Record 236 of 645 | buraydah
# Processing Record 237 of 645 | touros
# Processing Record 238 of 645 | mulchen
# Processing Record 239 of 645 | palmer
# Processing Record 240 of 645 | tuatapere
# Processing Record 241 of 645 | port macquarie
# City not found. Skipping....
# Processing Record 243 of 645 | mahon
# Processing Record 244 of 645 | mackay
# Processing Record 245 of 645 | belmonte
# Processing Record 246 of 645 | pasni
# Processing Record 247 of 645 | edd
# Processing Record 248 of 645 | luderitz
# Processing Record 249 of 645 | miyako
# Processing Record 250 of 645 | kruisfontein
# Processing Record 251 of 645 | pokhara
# Processing Record 252 of 645 | shurugwi
# Processing Record 253 of 645 | mehamn
# Processing Record 254 of 645 | broome
# Processing Record 255 of 645 | porosozero
# Processing Record 256 of 645 | richards bay
# Processing Record 257 of 645 | goderich
# City not found. Skipping....
# Processing Record 259 of 645 | ginda
# Processing Record 260 of 645 | ucluelet
# Processing Record 261 of 645 | jilib
# Processing Record 262 of 645 | sorland
# Processing Record 263 of 645 | smyshlyayevka
# Processing Record 264 of 645 | todos santos
# Processing Record 265 of 645 | grand gaube
# Processing Record 266 of 645 | pringsewu
# Processing Record 267 of 645 | roros
# City not found. Skipping....
# Processing Record 269 of 645 | san ramon
# Processing Record 270 of 645 | chegdomyn
# Processing Record 271 of 645 | norman wells
# Processing Record 272 of 645 | coutances
# Processing Record 273 of 645 | zemio
# Processing Record 274 of 645 | san quintin
# City not found. Skipping....
# Processing Record 276 of 645 | comodoro rivadavia
# Processing Record 277 of 645 | berlevag
# Processing Record 278 of 645 | bambanglipuro
# Processing Record 279 of 645 | havoysund
# Processing Record 280 of 645 | barra do garcas
# Processing Record 281 of 645 | kang
# Processing Record 282 of 645 | tahe
# Processing Record 283 of 645 | athabasca
# Processing Record 284 of 645 | souillac
# City not found. Skipping....
# City not found. Skipping....
# Processing Record 287 of 645 | nizwa
# Processing Record 288 of 645 | bowen
# Processing Record 289 of 645 | umm lajj
# City not found. Skipping....
# Processing Record 291 of 645 | zhob
# Processing Record 292 of 645 | pevek
# Processing Record 293 of 645 | valparaiso
# Processing Record 294 of 645 | baillif
# Processing Record 295 of 645 | victoria
# Processing Record 296 of 645 | sitka
# Processing Record 297 of 645 | kahului
# Processing Record 298 of 645 | stratford-upon-avon
# Processing Record 299 of 645 | gravdal
# Processing Record 300 of 645 | la ronge
# Processing Record 301 of 645 | geraldton
# Processing Record 302 of 645 | along
# City not found. Skipping....
# Processing Record 304 of 645 | clacton-on-sea
# Processing Record 305 of 645 | van buren
# City not found. Skipping....
# Processing Record 307 of 645 | qiongshan
# City not found. Skipping....
# Processing Record 309 of 645 | keetmanshoop
# Processing Record 310 of 645 | linxia
# Processing Record 311 of 645 | arraial do cabo
# Processing Record 312 of 645 | port moresby
# Processing Record 313 of 645 | kaitangata
# Processing Record 314 of 645 | berdigestyakh
# Processing Record 315 of 645 | celestun
# Processing Record 316 of 645 | ligayan
# Processing Record 317 of 645 | pyapon
# Processing Record 318 of 645 | henties bay
# Processing Record 319 of 645 | beringovskiy
# Processing Record 320 of 645 | saint george
# Processing Record 321 of 645 | suez
# Processing Record 322 of 645 | sungairaya
# Processing Record 323 of 645 | coahuayana
# Processing Record 324 of 645 | hualmay
# Processing Record 325 of 645 | kerrobert
# Processing Record 326 of 645 | ahipara
# Processing Record 327 of 645 | malakal
# Processing Record 328 of 645 | mujiayingzi
# City not found. Skipping....
# Processing Record 330 of 645 | bahia honda
# Processing Record 331 of 645 | aljezur
# Processing Record 332 of 645 | taoudenni
# Processing Record 333 of 645 | sabha
# Processing Record 334 of 645 | pitea
# Processing Record 335 of 645 | mitsamiouli
# Processing Record 336 of 645 | kisangani
# Processing Record 337 of 645 | balkhash
# Processing Record 338 of 645 | khandyga
# Processing Record 339 of 645 | sisimiut
# Processing Record 340 of 645 | clive
# Processing Record 341 of 645 | flinders
# Processing Record 342 of 645 | mnogovershinnyy
# Processing Record 343 of 645 | husi
# Processing Record 344 of 645 | tabou
# Processing Record 345 of 645 | port loko
# Processing Record 346 of 645 | siva
# Processing Record 347 of 645 | juneau
# Processing Record 348 of 645 | tiznit
# Processing Record 349 of 645 | toma
# Processing Record 350 of 645 | vostok
# City not found. Skipping....
# Processing Record 352 of 645 | tigil
# Processing Record 353 of 645 | khatanga
# Processing Record 354 of 645 | brownsville
# Processing Record 355 of 645 | southbridge
# Processing Record 356 of 645 | calais
# City not found. Skipping....
# Processing Record 358 of 645 | bubaque
# Processing Record 359 of 645 | pilar
# Processing Record 360 of 645 | catamarca
# Processing Record 361 of 645 | namatanai
# Processing Record 362 of 645 | sept-iles
# Processing Record 363 of 645 | ende
# Processing Record 364 of 645 | nhulunbuy
# Processing Record 365 of 645 | pitimbu
# Processing Record 366 of 645 | lata
# Processing Record 367 of 645 | kaeo
# Processing Record 368 of 645 | pontes e lacerda
# City not found. Skipping....
# Processing Record 370 of 645 | deniliquin
# Processing Record 371 of 645 | oyem
# Processing Record 372 of 645 | arman
# Processing Record 373 of 645 | balkanabat
# Processing Record 374 of 645 | tessalit
# Processing Record 375 of 645 | hukuntsi
# Processing Record 376 of 645 | chinique
# City not found. Skipping....
# Processing Record 378 of 645 | portland
# Processing Record 379 of 645 | najran
# City not found. Skipping....
# Processing Record 381 of 645 | shepsi
# Processing Record 382 of 645 | guiratinga
# Processing Record 383 of 645 | tarakan
# City not found. Skipping....
# Processing Record 385 of 645 | tondano
# Processing Record 386 of 645 | san cristobal
# Processing Record 387 of 645 | kefamenanu
# Processing Record 388 of 645 | la asuncion
# Processing Record 389 of 645 | barauna
# Processing Record 390 of 645 | hailin
# Processing Record 391 of 645 | amuntai
# Processing Record 392 of 645 | camocim
# Processing Record 393 of 645 | santa ines
# Processing Record 394 of 645 | sibolga
# Processing Record 395 of 645 | rodrigues alves
# Processing Record 396 of 645 | hokitika
# Processing Record 397 of 645 | salalah
# City not found. Skipping....
# Processing Record 399 of 645 | ponta do sol
# Processing Record 400 of 645 | garowe
# Processing Record 401 of 645 | danane
# City not found. Skipping....
# Processing Record 403 of 645 | nouakchott
# Processing Record 404 of 645 | boyolangu
# Processing Record 405 of 645 | inhambane
# Processing Record 406 of 645 | chumikan
# Processing Record 407 of 645 | graulhet
# City not found. Skipping....
# Processing Record 409 of 645 | dunedin
# Processing Record 410 of 645 | salinas
# Processing Record 411 of 645 | strezhevoy
# Processing Record 412 of 645 | vestmanna
# Processing Record 413 of 645 | razole
# Processing Record 414 of 645 | kahramanmaras
# Processing Record 415 of 645 | sao joao da barra
# Processing Record 416 of 645 | padang
# Processing Record 417 of 645 | pervomayskoye
# Processing Record 418 of 645 | kirovskiy
# Processing Record 419 of 645 | ayan
# Processing Record 420 of 645 | wamba
# Processing Record 421 of 645 | aktau
# Processing Record 422 of 645 | bilibino
# Processing Record 423 of 645 | spokane
# City not found. Skipping....
# Processing Record 425 of 645 | nantucket
# Processing Record 426 of 645 | yar-sale
# Processing Record 427 of 645 | praya
# Processing Record 428 of 645 | adrar
# Processing Record 429 of 645 | nexo
# Processing Record 430 of 645 | hami
# Processing Record 431 of 645 | atar
# Processing Record 432 of 645 | santiago
# Processing Record 433 of 645 | alice springs
# Processing Record 434 of 645 | huilong
# Processing Record 435 of 645 | fethiye
# Processing Record 436 of 645 | nogliki
# Processing Record 437 of 645 | xuddur
# Processing Record 438 of 645 | iquique
# Processing Record 439 of 645 | necochea
# Processing Record 440 of 645 | general roca
# Processing Record 441 of 645 | coro
# Processing Record 442 of 645 | konstantinovka
# Processing Record 443 of 645 | aripuana
# Processing Record 444 of 645 | quang ngai
# Processing Record 445 of 645 | biak
# Processing Record 446 of 645 | nibe
# Processing Record 447 of 645 | ixtapa
# Processing Record 448 of 645 | longyearbyen
# Processing Record 449 of 645 | yulara
# Processing Record 450 of 645 | dumas
# Processing Record 451 of 645 | acapulco
# Processing Record 452 of 645 | rosarito
# Processing Record 453 of 645 | tolaga bay
# City not found. Skipping....
# Processing Record 455 of 645 | omsukchan
# Processing Record 456 of 645 | havelock
# Processing Record 457 of 645 | zyryanka
# Processing Record 458 of 645 | mezen
# Processing Record 459 of 645 | robertsport
# Processing Record 460 of 645 | maumere
# Processing Record 461 of 645 | dingolfing
# Processing Record 462 of 645 | nizhniy baskunchak
# Processing Record 463 of 645 | paita
# Processing Record 464 of 645 | chalmette
# Processing Record 465 of 645 | santa cruz
# Processing Record 466 of 645 | visby
# Processing Record 467 of 645 | boralday
# City not found. Skipping....
# Processing Record 469 of 645 | soyo
# Processing Record 470 of 645 | nabire
# Processing Record 471 of 645 | saint-augustin
# Processing Record 472 of 645 | abu samrah
# Processing Record 473 of 645 | kununurra
# Processing Record 474 of 645 | shimoda
# Processing Record 475 of 645 | noumea
# Processing Record 476 of 645 | ostrovnoy
# Processing Record 477 of 645 | tombouctou
# Processing Record 478 of 645 | pingliang
# Processing Record 479 of 645 | tura
# Processing Record 480 of 645 | qui nhon
# Processing Record 481 of 645 | inuvik
# Processing Record 482 of 645 | rakaia
# Processing Record 483 of 645 | tilichiki
# Processing Record 484 of 645 | anloga
# Processing Record 485 of 645 | lahat
# Processing Record 486 of 645 | cortes
# Processing Record 487 of 645 | tomatlan
# Processing Record 488 of 645 | los llanos de aridane
# Processing Record 489 of 645 | port elizabeth
# Processing Record 490 of 645 | walvis bay
# Processing Record 491 of 645 | williams lake
# Processing Record 492 of 645 | charters towers
# Processing Record 493 of 645 | sao jose da coroa grande
# Processing Record 494 of 645 | mount gambier
# Processing Record 495 of 645 | yorkton
# Processing Record 496 of 645 | yuksekova
# Processing Record 497 of 645 | chilmari
# Processing Record 498 of 645 | flin flon
# City not found. Skipping....
# Processing Record 500 of 645 | zhengjiatun
# Processing Record 501 of 645 | sigiriya
# Processing Record 502 of 645 | glomfjord
# Processing Record 503 of 645 | santa luzia
# Processing Record 504 of 645 | dongsheng
# Processing Record 505 of 645 | vila franca do campo
# Processing Record 506 of 645 | big rapids
# Processing Record 507 of 645 | slave lake
# Processing Record 508 of 645 | kermanshah
# Processing Record 509 of 645 | kiunga
# Processing Record 510 of 645 | salamiyah
# Processing Record 511 of 645 | powell river
# Processing Record 512 of 645 | kuytun
# Processing Record 513 of 645 | guamuchil
# City not found. Skipping....
# Processing Record 515 of 645 | royan
# Processing Record 516 of 645 | cabo san lucas
# Processing Record 517 of 645 | prince rupert
# Processing Record 518 of 645 | astana
# Processing Record 519 of 645 | adre
# City not found. Skipping....
# Processing Record 521 of 645 | aksha
# Processing Record 522 of 645 | skibbereen
# Processing Record 523 of 645 | lingao
# Processing Record 524 of 645 | zhanaozen
# Processing Record 525 of 645 | seryshevo
# Processing Record 526 of 645 | nishihara
# Processing Record 527 of 645 | cidreira
# Processing Record 528 of 645 | iqaluit
# Processing Record 529 of 645 | maroantsetra
# Processing Record 530 of 645 | puerto escondido
# Processing Record 531 of 645 | victoria point
# Processing Record 532 of 645 | yerbogachen
# Processing Record 533 of 645 | klaksvik
# Processing Record 534 of 645 | ciudad bolivar
# Processing Record 535 of 645 | beloha
# Processing Record 536 of 645 | shimanovsk
# Processing Record 537 of 645 | matay
# Processing Record 538 of 645 | laguna
# Processing Record 539 of 645 | bombarral
# Processing Record 540 of 645 | general pico
# Processing Record 541 of 645 | itarema
# Processing Record 542 of 645 | nome
# Processing Record 543 of 645 | nuuk
# Processing Record 544 of 645 | feijo
# Processing Record 545 of 645 | khed brahma
# Processing Record 546 of 645 | mandera
# Processing Record 547 of 645 | erzin
# Processing Record 548 of 645 | jizan
# Processing Record 549 of 645 | chegutu
# Processing Record 550 of 645 | innisfail
# Processing Record 551 of 645 | kholm
# Processing Record 552 of 645 | pistoia
# Processing Record 553 of 645 | sinnamary
# Processing Record 554 of 645 | khani
# Processing Record 555 of 645 | punta gorda
# Processing Record 556 of 645 | ulaangom
# Processing Record 557 of 645 | leningradskiy
# Processing Record 558 of 645 | labuhan
# Processing Record 559 of 645 | srivardhan
# Processing Record 560 of 645 | wundanyi
# Processing Record 561 of 645 | shuangcheng
# Processing Record 562 of 645 | gatehouse of fleet
# Processing Record 563 of 645 | plymouth
# Processing Record 564 of 645 | kalabo
# Processing Record 565 of 645 | saint-ambroise
# Processing Record 566 of 645 | kautokeino
# Processing Record 567 of 645 | damietta
# Processing Record 568 of 645 | ngunguru
# City not found. Skipping....
# Processing Record 570 of 645 | san policarpo
# Processing Record 571 of 645 | guadalupe y calvo
# Processing Record 572 of 645 | kachhwa
# City not found. Skipping....
# Processing Record 574 of 645 | macomb
# Processing Record 575 of 645 | kapiri mposhi
# Processing Record 576 of 645 | aleksandrovsk-sakhalinskiy
# Processing Record 577 of 645 | faya
# Processing Record 578 of 645 | miram shah
# Processing Record 579 of 645 | zwedru
# Processing Record 580 of 645 | cam ranh
# Processing Record 581 of 645 | tshela
# Processing Record 582 of 645 | cap malheureux
# Processing Record 583 of 645 | jieshi
# Processing Record 584 of 645 | port blair
# Processing Record 585 of 645 | champerico
# City not found. Skipping....
# Processing Record 587 of 645 | la cruz
# Processing Record 588 of 645 | achacachi
# Processing Record 589 of 645 | chiredzi
# Processing Record 590 of 645 | tokur
# Processing Record 591 of 645 | nouadhibou
# Processing Record 592 of 645 | sampit
# Processing Record 593 of 645 | kuchera
# Processing Record 594 of 645 | chistogorskiy
# Processing Record 595 of 645 | luwuk
# Processing Record 596 of 645 | teahupoo
# Processing Record 597 of 645 | sakakah
# City not found. Skipping....
# Processing Record 599 of 645 | bay roberts
# Processing Record 600 of 645 | dubova
# Processing Record 601 of 645 | oxelosund
# Processing Record 602 of 645 | igboho
# City not found. Skipping....
# Processing Record 604 of 645 | huicungo
# Processing Record 605 of 645 | vestmannaeyjar
# Processing Record 606 of 645 | miranda
# City not found. Skipping....
# Processing Record 608 of 645 | kijang
# Processing Record 609 of 645 | bouna
# Processing Record 610 of 645 | arboletes
# Processing Record 611 of 645 | andover
# Processing Record 612 of 645 | huarmey
# Processing Record 613 of 645 | haimen
# City not found. Skipping....
# Processing Record 615 of 645 | mariinsk
# Processing Record 616 of 645 | hofn
# Processing Record 617 of 645 | saint anthony
# City not found. Skipping....
# Processing Record 619 of 645 | longjiang
# Processing Record 620 of 645 | fairbanks
# Processing Record 621 of 645 | coxim
# City not found. Skipping....
# Processing Record 623 of 645 | port hueneme
# Processing Record 624 of 645 | namibe
# Processing Record 625 of 645 | dvinskoy
# Processing Record 626 of 645 | tual
# Processing Record 627 of 645 | ancud
# Processing Record 628 of 645 | hede
# Processing Record 629 of 645 | tagusao
# Processing Record 630 of 645 | eisiskes
# Processing Record 631 of 645 | caohai
# Processing Record 632 of 645 | kirakira
# Processing Record 633 of 645 | muros
# Processing Record 634 of 645 | jalu
# Processing Record 635 of 645 | siniscola
# Processing Record 636 of 645 | sabang
# Processing Record 637 of 645 | gizo
# Processing Record 638 of 645 | salekhard
# Processing Record 639 of 645 | oltu
# City not found. Skipping....
# Processing Record 641 of 645 | bitung
# Processing Record 642 of 645 | santiago del estero
# Processing Record 643 of 645 | caravelas
# Processing Record 644 of 645 | tsumeb
# Processing Record 645 of 645 | boa vista
# --------------------------------
# Data Retrieval Complete
# --------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({"City": city_name, "Lat":lat, "Lng":lng,"Max Temp": max_temp, 
                           "Humidity":humidity, "Cloudiness": cloud, "Wind Speed": wind_speed, 
                          "Country":country, "Date": date})
weather_df.head()
# Out:
#                 City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Plácido de Castro -10.34  -67.19     75.99        92         100
# 1            Mataura -46.19  168.86     55.00        97         100
# 2            Isangel -19.55  169.27     75.63        80          49
# 3          Saquarema -22.92  -42.51     77.00        88          75
# 4    Haines Junction  60.75 -137.51     21.20        79         100
#
#    Wind Speed Country        Date
# 0        8.25      BR  1604083401
# 1        5.01      NZ  1604083154
# 2       12.88      VU  1604083296
# 3       12.75      BR  1604083161
# 4       11.41      CA  1604083327

# %%
weather_df.to_csv('output.csv', index = False)

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  588.000000  588.000000  588.000000  588.000000  588.000000  588.000000
# mean    19.884864   20.194864   59.258061   71.331633   53.183673    8.195408
# std     33.023733   89.788513   22.714670   21.171416   40.803434    5.848276
# min    -54.800000 -175.200000  -20.200000    6.000000    0.000000    0.270000
# 25%     -7.537500  -58.890000   43.927500   59.000000    3.000000    3.960000
# 50%     22.915000   22.915000   64.635000   76.000000   67.000000    6.760000
# 75%     48.475000  103.590000   77.667500   88.000000   96.000000   11.270000
# max     78.220000  179.320000   99.320000  100.000000  100.000000   33.330000
#
#                Date
# count  5.880000e+02
# mean   1.604083e+09
# std    1.236664e+02
# min    1.604083e+09
# 25%    1.604083e+09
# 50%    1.604083e+09
# 75%    1.604083e+09
# max    1.604083e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
latitude = weather_df['Lat']
temperature = weather_df['Max Temp']

plt.scatter(latitude, temperature, edgecolor = "black")
plt.title("City Latitude vs. Max Temperature (30/10/20)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig('Images/Latitude_vs_ Temp.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
latitude = weather_df['Lat']
humidity = weather_df['Humidity']

plt.scatter(latitude, humidity, facecolor = 'red',edgecolor = "black")
plt.title("City Latitude vs. Humidity (30/10/20)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig('Images/Latitude_vs_ Humidity.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
latitude = weather_df['Lat']
cloudiness = weather_df['Cloudiness']

plt.scatter(latitude, cloudiness, facecolor = 'green',edgecolor = "black")
plt.title("City Latitude vs. Cloudiness (30/10/20)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig('Images/Latitude_vs_ Cloudiness.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
latitude = weather_df['Lat']
wind_speed = weather_df['Wind Speed']

plt.scatter(latitude, wind_speed, facecolor = 'orange',edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (30/10/20)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig('Images/Latitude_vs_ Wind.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
northern_hem = weather_df.loc[weather_df['Lat']>0]
southern_hem = weather_df.loc[weather_df['Lat']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
latitude = northern_hem['Lat']
temperature = northern_hem['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, temperature)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, temperature)
plt.title("Northern Hemisphere - Max Temp vs. Latitude")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(15,-20),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/NH_Latitude_vs_ Temp.png')
plt.show()
# Out:
# The r-value is: 0.7702052959336148

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
latitude = southern_hem['Lat']
temperature = southern_hem['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, temperature)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, temperature)
plt.title("Southern Hemisphere - Max Temp vs. Latitude")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(-20,50),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/SH_Latitude_vs_ Temp.png')
plt.show()
# Out:
# The r-value is: 0.4984026915682892

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
latitude = northern_hem['Lat']
humidity = northern_hem['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, humidity)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, humidity)
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/NH_Latitude_vs_ Humidity.png')
plt.show()
# Out:
# The r-value is: 0.12630887386781736

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
latitude = southern_hem['Lat']
humidity = southern_hem['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, humidity)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, humidity)
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/SH_Latitude_vs_ Humidity.png')
plt.show()
# Out:
# The r-value is: 6.546130490939943e-05

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
latitude = northern_hem['Lat']
cloudiness = northern_hem['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, cloudiness)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, cloudiness)
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(40,5),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/NH_Latitude_vs_ Cloudiness.png')
plt.show()
# Out:
# The r-value is: 0.019445155992265678

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
latitude = southern_hem['Lat']
cloudiness = southern_hem['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, cloudiness)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, cloudiness)
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(-55,25),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/SH_Latitude_vs_ Cloudiness.png')
plt.show()
# Out:
# The r-value is: 0.025926924980381873

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
latitude = northern_hem['Lat']
wind_speed = northern_hem['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, wind_speed)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, wind_speed)
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude")
plt.ylabel("Wind Speed(mph)")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(20,30),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/NH_Latitude_vs_ Wind.png')
plt.show()
# Out:
# The r-value is: 0.000200400875065237

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
latitude = southern_hem['Lat']
wind_speed = southern_hem['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, wind_speed)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, wind_speed)
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude")
plt.ylabel("Wind Speed(mph)")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/SH_Latitude_vs_ Wind.png')
plt.show()
# Out:
# The r-value is: 0.016088678196257724
