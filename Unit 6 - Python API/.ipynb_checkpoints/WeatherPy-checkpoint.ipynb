# %% [markdown]
# # WeatherPy
# ----

# %% [markdown]
# ###   Analysis:
#
# * As cities approach the equator (Latitude = 0), they have a higher maximum temperature.
# * There is not a strong correlation between latitude and either humidity, cloudiness, or windspeed.
# * In the northern hemisphere on the date that the data was pulled (Oct 30, 2020) there is a high proportion of cities with humidity of greater than 60%.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

from pprint import pprint

# Import API key
weather_api_key = "4b0e3b0aab2982b37f2f4173ef8a6955"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 603

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?'
units = "imperial"
lat = []
lng = []
max_temp =[]
humidity = []
cloud = []
wind_speed = []
country = []
date = []
city_name = []
x = 1

for city in cities:
    try:
        query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
        response = requests.get(query_url).json()
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        city_name.append(response['name'])
        print(f"Processing Record {x} of {len(cities)} | {city}")
    except:
        print("City not found. Skipping....")
    x=x+1

print("--------------------------------")
print("Data Retrieval Complete")
print("--------------------------------")
# Out:
# Processing Record 1 of 603 | chicama
# Processing Record 2 of 603 | busselton
# Processing Record 3 of 603 | sampit
# Processing Record 4 of 603 | san ramon de la nueva oran
# Processing Record 5 of 603 | bredasdorp
# City not found. Skipping....
# Processing Record 7 of 603 | punta arenas
# Processing Record 8 of 603 | ahipara
# City not found. Skipping....
# Processing Record 10 of 603 | anadyr
# Processing Record 11 of 603 | cape town
# City not found. Skipping....
# Processing Record 13 of 603 | pionerskiy
# Processing Record 14 of 603 | ust-shonosha
# Processing Record 15 of 603 | butaritari
# Processing Record 16 of 603 | vostok
# Processing Record 17 of 603 | clyde river
# City not found. Skipping....
# Processing Record 19 of 603 | luderitz
# Processing Record 20 of 603 | arraial do cabo
# Processing Record 21 of 603 | kapaa
# Processing Record 22 of 603 | kaitangata
# City not found. Skipping....
# Processing Record 24 of 603 | juegang
# Processing Record 25 of 603 | albany
# Processing Record 26 of 603 | saskylakh
# Processing Record 27 of 603 | ushuaia
# Processing Record 28 of 603 | la primavera
# Processing Record 29 of 603 | new norfolk
# Processing Record 30 of 603 | castro
# Processing Record 31 of 603 | avarua
# Processing Record 32 of 603 | bethel
# Processing Record 33 of 603 | mahebourg
# Processing Record 34 of 603 | victoria
# Processing Record 35 of 603 | olinda
# Processing Record 36 of 603 | la rioja
# Processing Record 37 of 603 | isiro
# Processing Record 38 of 603 | khandyga
# Processing Record 39 of 603 | kodiak
# City not found. Skipping....
# Processing Record 41 of 603 | yazman
# Processing Record 42 of 603 | taree
# Processing Record 43 of 603 | aginskoye
# Processing Record 44 of 603 | antalaha
# Processing Record 45 of 603 | georgetown
# City not found. Skipping....
# Processing Record 47 of 603 | tura
# Processing Record 48 of 603 | vaini
# Processing Record 49 of 603 | airai
# Processing Record 50 of 603 | sar-e pul
# Processing Record 51 of 603 | kasempa
# Processing Record 52 of 603 | abu samrah
# Processing Record 53 of 603 | tuktoyaktuk
# Processing Record 54 of 603 | fairbanks
# Processing Record 55 of 603 | kruisfontein
# Processing Record 56 of 603 | rikitea
# Processing Record 57 of 603 | cayenne
# Processing Record 58 of 603 | mount gambier
# Processing Record 59 of 603 | beringovskiy
# Processing Record 60 of 603 | srednekolymsk
# Processing Record 61 of 603 | artigas
# City not found. Skipping....
# Processing Record 63 of 603 | touros
# Processing Record 64 of 603 | mtsensk
# Processing Record 65 of 603 | hobart
# City not found. Skipping....
# Processing Record 67 of 603 | hithadhoo
# Processing Record 68 of 603 | george town
# Processing Record 69 of 603 | dinguiraye
# Processing Record 70 of 603 | farafangana
# Processing Record 71 of 603 | los llanos de aridane
# Processing Record 72 of 603 | bluff
# Processing Record 73 of 603 | hermanus
# Processing Record 74 of 603 | severo-kurilsk
# Processing Record 75 of 603 | kysyl-syr
# Processing Record 76 of 603 | axim
# Processing Record 77 of 603 | san andres
# Processing Record 78 of 603 | santa cruz
# Processing Record 79 of 603 | yar-sale
# Processing Record 80 of 603 | upernavik
# Processing Record 81 of 603 | brazzaville
# Processing Record 82 of 603 | qaanaaq
# Processing Record 83 of 603 | alice springs
# City not found. Skipping....
# Processing Record 85 of 603 | basco
# Processing Record 86 of 603 | puerto ayora
# Processing Record 87 of 603 | narsaq
# Processing Record 88 of 603 | zhezkazgan
# Processing Record 89 of 603 | biarritz
# Processing Record 90 of 603 | tateyama
# Processing Record 91 of 603 | bambous virieux
# Processing Record 92 of 603 | yellowknife
# Processing Record 93 of 603 | mataura
# Processing Record 94 of 603 | kulu
# Processing Record 95 of 603 | tari
# Processing Record 96 of 603 | havoysund
# Processing Record 97 of 603 | lavumisa
# Processing Record 98 of 603 | mar del plata
# Processing Record 99 of 603 | adrar
# Processing Record 100 of 603 | las vegas
# Processing Record 101 of 603 | ewa beach
# Processing Record 102 of 603 | port-gentil
# City not found. Skipping....
# Processing Record 104 of 603 | lorengau
# Processing Record 105 of 603 | changji
# Processing Record 106 of 603 | awash
# Processing Record 107 of 603 | east london
# Processing Record 108 of 603 | vardo
# Processing Record 109 of 603 | bengkulu
# Processing Record 110 of 603 | buenos aires
# Processing Record 111 of 603 | haines junction
# Processing Record 112 of 603 | jamestown
# Processing Record 113 of 603 | coahuayana
# Processing Record 114 of 603 | lebu
# Processing Record 115 of 603 | hilo
# Processing Record 116 of 603 | port alfred
# Processing Record 117 of 603 | sembakung
# Processing Record 118 of 603 | bay roberts
# Processing Record 119 of 603 | grindavik
# Processing Record 120 of 603 | lernapat
# Processing Record 121 of 603 | kualakapuas
# Processing Record 122 of 603 | samarai
# City not found. Skipping....
# Processing Record 124 of 603 | rio gallegos
# Processing Record 125 of 603 | myskhako
# Processing Record 126 of 603 | avera
# Processing Record 127 of 603 | port blair
# Processing Record 128 of 603 | chuy
# Processing Record 129 of 603 | tambopata
# Processing Record 130 of 603 | pauini
# Processing Record 131 of 603 | mezen
# Processing Record 132 of 603 | ribeira grande
# Processing Record 133 of 603 | goderich
# Processing Record 134 of 603 | tarko-sale
# Processing Record 135 of 603 | kharhial
# Processing Record 136 of 603 | hervey bay
# Processing Record 137 of 603 | ponta do sol
# Processing Record 138 of 603 | nikolskoye
# Processing Record 139 of 603 | cidreira
# City not found. Skipping....
# Processing Record 141 of 603 | ancud
# Processing Record 142 of 603 | thompson
# Processing Record 143 of 603 | makakilo city
# Processing Record 144 of 603 | nome
# Processing Record 145 of 603 | saint-philippe
# Processing Record 146 of 603 | cumbitara
# Processing Record 147 of 603 | kahului
# Processing Record 148 of 603 | hovd
# Processing Record 149 of 603 | san patricio
# Processing Record 150 of 603 | olafsvik
# Processing Record 151 of 603 | warka
# City not found. Skipping....
# Processing Record 153 of 603 | kirensk
# Processing Record 154 of 603 | maningrida
# Processing Record 155 of 603 | butiama
# Processing Record 156 of 603 | longyearbyen
# Processing Record 157 of 603 | dalbandin
# Processing Record 158 of 603 | troitsko-pechorsk
# Processing Record 159 of 603 | berlevag
# Processing Record 160 of 603 | pahrump
# Processing Record 161 of 603 | pevek
# Processing Record 162 of 603 | tasiilaq
# Processing Record 163 of 603 | jutai
# Processing Record 164 of 603 | cabo san lucas
# Processing Record 165 of 603 | faya
# Processing Record 166 of 603 | minna
# Processing Record 167 of 603 | egvekinot
# Processing Record 168 of 603 | omsukchan
# Processing Record 169 of 603 | araripina
# Processing Record 170 of 603 | nuuk
# Processing Record 171 of 603 | poum
# Processing Record 172 of 603 | cairns
# Processing Record 173 of 603 | aztec
# Processing Record 174 of 603 | novyy urengoy
# Processing Record 175 of 603 | cermik
# Processing Record 176 of 603 | conceicao do araguaia
# Processing Record 177 of 603 | tangzhai
# Processing Record 178 of 603 | dergachi
# Processing Record 179 of 603 | guerrero negro
# Processing Record 180 of 603 | atuona
# Processing Record 181 of 603 | carnarvon
# Processing Record 182 of 603 | sioux falls
# City not found. Skipping....
# Processing Record 184 of 603 | tazovskiy
# Processing Record 185 of 603 | souillac
# Processing Record 186 of 603 | gizo
# City not found. Skipping....
# Processing Record 188 of 603 | bontang
# Processing Record 189 of 603 | kargasok
# Processing Record 190 of 603 | oum hadjer
# Processing Record 191 of 603 | isangel
# Processing Record 192 of 603 | inirida
# Processing Record 193 of 603 | dombarovskiy
# Processing Record 194 of 603 | klaksvik
# Processing Record 195 of 603 | jijiga
# Processing Record 196 of 603 | dikson
# Processing Record 197 of 603 | miranda
# Processing Record 198 of 603 | banda aceh
# Processing Record 199 of 603 | faanui
# City not found. Skipping....
# Processing Record 201 of 603 | mitsamiouli
# Processing Record 202 of 603 | sitka
# Processing Record 203 of 603 | inhambane
# Processing Record 204 of 603 | kununurra
# Processing Record 205 of 603 | narathiwat
# City not found. Skipping....
# Processing Record 207 of 603 | bowen
# Processing Record 208 of 603 | lac du bonnet
# Processing Record 209 of 603 | rancho palos verdes
# Processing Record 210 of 603 | tandil
# City not found. Skipping....
# Processing Record 212 of 603 | barcelos
# Processing Record 213 of 603 | magistralnyy
# City not found. Skipping....
# Processing Record 215 of 603 | hasaki
# Processing Record 216 of 603 | tiksi
# Processing Record 217 of 603 | tiznit
# Processing Record 218 of 603 | karratha
# Processing Record 219 of 603 | khatanga
# Processing Record 220 of 603 | mangaratiba
# Processing Record 221 of 603 | batemans bay
# Processing Record 222 of 603 | grand haven
# Processing Record 223 of 603 | flinders
# City not found. Skipping....
# Processing Record 225 of 603 | kichera
# Processing Record 226 of 603 | springbok
# Processing Record 227 of 603 | geraldton
# Processing Record 228 of 603 | vozdvizhenka
# Processing Record 229 of 603 | saint-pierre
# Processing Record 230 of 603 | soto la marina
# Processing Record 231 of 603 | barrow
# City not found. Skipping....
# Processing Record 233 of 603 | arlit
# Processing Record 234 of 603 | urumqi
# Processing Record 235 of 603 | enshi
# Processing Record 236 of 603 | port elizabeth
# Processing Record 237 of 603 | chokurdakh
# Processing Record 238 of 603 | gemena
# Processing Record 239 of 603 | reidsville
# Processing Record 240 of 603 | umm lajj
# Processing Record 241 of 603 | tete
# Processing Record 242 of 603 | socorro
# Processing Record 243 of 603 | imphal
# Processing Record 244 of 603 | bathsheba
# Processing Record 245 of 603 | nantucket
# Processing Record 246 of 603 | hami
# Processing Record 247 of 603 | port lincoln
# Processing Record 248 of 603 | mareeba
# Processing Record 249 of 603 | nuevo progreso
# Processing Record 250 of 603 | vanderhoof
# Processing Record 251 of 603 | bulaevo
# Processing Record 252 of 603 | pithora
# Processing Record 253 of 603 | bilibino
# Processing Record 254 of 603 | mount pleasant
# Processing Record 255 of 603 | bismarck
# Processing Record 256 of 603 | chauk
# Processing Record 257 of 603 | isabela
# Processing Record 258 of 603 | pimenta bueno
# Processing Record 259 of 603 | san cristobal
# Processing Record 260 of 603 | vorukh
# Processing Record 261 of 603 | shagonar
# Processing Record 262 of 603 | lompoc
# Processing Record 263 of 603 | pisco
# Processing Record 264 of 603 | namibe
# City not found. Skipping....
# Processing Record 266 of 603 | elko
# Processing Record 267 of 603 | gigmoto
# Processing Record 268 of 603 | vila franca do campo
# Processing Record 269 of 603 | fort-shevchenko
# Processing Record 270 of 603 | sarangani
# City not found. Skipping....
# Processing Record 272 of 603 | bar
# Processing Record 273 of 603 | deputatskiy
# Processing Record 274 of 603 | norman wells
# Processing Record 275 of 603 | byron bay
# Processing Record 276 of 603 | coihaique
# Processing Record 277 of 603 | te anau
# Processing Record 278 of 603 | kouango
# Processing Record 279 of 603 | labrea
# Processing Record 280 of 603 | pangnirtung
# Processing Record 281 of 603 | palmer
# City not found. Skipping....
# Processing Record 283 of 603 | portland
# Processing Record 284 of 603 | iquitos
# Processing Record 285 of 603 | comodoro rivadavia
# City not found. Skipping....
# Processing Record 287 of 603 | higueron
# Processing Record 288 of 603 | codrington
# Processing Record 289 of 603 | gharghoda
# Processing Record 290 of 603 | kathmandu
# Processing Record 291 of 603 | marathon
# City not found. Skipping....
# Processing Record 293 of 603 | la ronge
# Processing Record 294 of 603 | nieuw amsterdam
# Processing Record 295 of 603 | shahrud
# Processing Record 296 of 603 | skaerbaek
# Processing Record 297 of 603 | sao filipe
# Processing Record 298 of 603 | carutapera
# Processing Record 299 of 603 | jacareacanga
# Processing Record 300 of 603 | surin
# Processing Record 301 of 603 | paamiut
# Processing Record 302 of 603 | sokolo
# Processing Record 303 of 603 | vestmanna
# Processing Record 304 of 603 | meulaboh
# Processing Record 305 of 603 | lampa
# Processing Record 306 of 603 | alofi
# Processing Record 307 of 603 | kostomuksha
# Processing Record 308 of 603 | sola
# Processing Record 309 of 603 | ngunguru
# Processing Record 310 of 603 | sinjar
# Processing Record 311 of 603 | taoudenni
# Processing Record 312 of 603 | nanortalik
# Processing Record 313 of 603 | den helder
# Processing Record 314 of 603 | dingle
# Processing Record 315 of 603 | karimganj
# Processing Record 316 of 603 | winsum
# Processing Record 317 of 603 | tilichiki
# Processing Record 318 of 603 | atyrau
# Processing Record 319 of 603 | longkou
# Processing Record 320 of 603 | sivaki
# Processing Record 321 of 603 | turukhansk
# Processing Record 322 of 603 | saldanha
# City not found. Skipping....
# Processing Record 324 of 603 | yuli
# Processing Record 325 of 603 | college
# Processing Record 326 of 603 | arraias
# Processing Record 327 of 603 | kabugao
# Processing Record 328 of 603 | salalah
# Processing Record 329 of 603 | constitucion
# Processing Record 330 of 603 | ariquemes
# Processing Record 331 of 603 | itigi
# City not found. Skipping....
# Processing Record 333 of 603 | masuguru
# Processing Record 334 of 603 | whakatane
# Processing Record 335 of 603 | tiarei
# Processing Record 336 of 603 | vao
# Processing Record 337 of 603 | buala
# Processing Record 338 of 603 | tabou
# Processing Record 339 of 603 | batagay-alyta
# City not found. Skipping....
# Processing Record 341 of 603 | sri aman
# Processing Record 342 of 603 | kayes
# Processing Record 343 of 603 | garza garcia
# Processing Record 344 of 603 | chifeng
# Processing Record 345 of 603 | orlik
# Processing Record 346 of 603 | kieta
# Processing Record 347 of 603 | arenal
# Processing Record 348 of 603 | dhamtari
# Processing Record 349 of 603 | zhuanghe
# City not found. Skipping....
# Processing Record 351 of 603 | sawtell
# Processing Record 352 of 603 | stolbishche
# Processing Record 353 of 603 | hobyo
# Processing Record 354 of 603 | acapulco
# Processing Record 355 of 603 | beloha
# Processing Record 356 of 603 | kloulklubed
# Processing Record 357 of 603 | praya
# Processing Record 358 of 603 | provideniya
# Processing Record 359 of 603 | ilulissat
# Processing Record 360 of 603 | george
# Processing Record 361 of 603 | esperance
# Processing Record 362 of 603 | grand island
# Processing Record 363 of 603 | itoman
# Processing Record 364 of 603 | saint george
# Processing Record 365 of 603 | yulara
# Processing Record 366 of 603 | cabedelo
# Processing Record 367 of 603 | thanh hoa
# Processing Record 368 of 603 | kavieng
# Processing Record 369 of 603 | batsfjord
# Processing Record 370 of 603 | goundam
# Processing Record 371 of 603 | shahr-e babak
# Processing Record 372 of 603 | cordoba
# Processing Record 373 of 603 | winnemucca
# Processing Record 374 of 603 | san javier
# City not found. Skipping....
# Processing Record 376 of 603 | qasigiannguit
# Processing Record 377 of 603 | rocha
# Processing Record 378 of 603 | manhuacu
# Processing Record 379 of 603 | benxi
# Processing Record 380 of 603 | port moresby
# Processing Record 381 of 603 | aksarka
# Processing Record 382 of 603 | ambunti
# City not found. Skipping....
# Processing Record 384 of 603 | kawalu
# Processing Record 385 of 603 | doaba
# Processing Record 386 of 603 | henties bay
# Processing Record 387 of 603 | milkovo
# Processing Record 388 of 603 | praia da vitoria
# Processing Record 389 of 603 | tukrah
# Processing Record 390 of 603 | ponta delgada
# Processing Record 391 of 603 | uyemskiy
# Processing Record 392 of 603 | derzhavinsk
# Processing Record 393 of 603 | kolyubakino
# Processing Record 394 of 603 | andilamena
# Processing Record 395 of 603 | sibenik
# Processing Record 396 of 603 | chippewa falls
# Processing Record 397 of 603 | coquimbo
# Processing Record 398 of 603 | rio grande
# Processing Record 399 of 603 | puerto colombia
# Processing Record 400 of 603 | carahue
# City not found. Skipping....
# Processing Record 402 of 603 | hay river
# Processing Record 403 of 603 | saint-augustin
# City not found. Skipping....
# Processing Record 405 of 603 | mount darwin
# Processing Record 406 of 603 | pacific grove
# Processing Record 407 of 603 | junagarh
# Processing Record 408 of 603 | mahibadhoo
# Processing Record 409 of 603 | ulladulla
# Processing Record 410 of 603 | visnes
# Processing Record 411 of 603 | husavik
# Processing Record 412 of 603 | pokhara
# Processing Record 413 of 603 | ankang
# Processing Record 414 of 603 | nabire
# Processing Record 415 of 603 | gobabis
# Processing Record 416 of 603 | iskateley
# Processing Record 417 of 603 | beberibe
# City not found. Skipping....
# Processing Record 419 of 603 | gidole
# Processing Record 420 of 603 | cockburn town
# Processing Record 421 of 603 | salinas
# Processing Record 422 of 603 | yakima
# Processing Record 423 of 603 | noumea
# Processing Record 424 of 603 | umm kaddadah
# Processing Record 425 of 603 | broome
# Processing Record 426 of 603 | king city
# Processing Record 427 of 603 | cozumel
# Processing Record 428 of 603 | coro
# Processing Record 429 of 603 | mairi
# Processing Record 430 of 603 | gorey
# Processing Record 431 of 603 | asau
# Processing Record 432 of 603 | sehithwa
# Processing Record 433 of 603 | jaisalmer
# Processing Record 434 of 603 | olhao
# Processing Record 435 of 603 | cherskiy
# Processing Record 436 of 603 | oussouye
# Processing Record 437 of 603 | north bend
# Processing Record 438 of 603 | abu dhabi
# Processing Record 439 of 603 | vanimo
# City not found. Skipping....
# Processing Record 441 of 603 | luena
# Processing Record 442 of 603 | rochefort
# Processing Record 443 of 603 | xiuyan
# Processing Record 444 of 603 | okhotsk
# Processing Record 445 of 603 | inongo
# Processing Record 446 of 603 | toamasina
# Processing Record 447 of 603 | madang
# Processing Record 448 of 603 | kyra
# Processing Record 449 of 603 | key largo
# Processing Record 450 of 603 | kangaatsiaq
# Processing Record 451 of 603 | sevsk
# Processing Record 452 of 603 | mutis
# Processing Record 453 of 603 | gonda
# Processing Record 454 of 603 | lubango
# Processing Record 455 of 603 | chokwe
# Processing Record 456 of 603 | lagoa
# Processing Record 457 of 603 | hun
# Processing Record 458 of 603 | leningradskiy
# Processing Record 459 of 603 | cervo
# Processing Record 460 of 603 | ekhabi
# Processing Record 461 of 603 | mackay
# Processing Record 462 of 603 | helong
# Processing Record 463 of 603 | vila velha
# Processing Record 464 of 603 | kavaratti
# Processing Record 465 of 603 | oriximina
# Processing Record 466 of 603 | flin flon
# Processing Record 467 of 603 | dudinka
# Processing Record 468 of 603 | san quintin
# Processing Record 469 of 603 | olga
# Processing Record 470 of 603 | iqaluit
# Processing Record 471 of 603 | middelburg
# Processing Record 472 of 603 | jinxiang
# City not found. Skipping....
# Processing Record 474 of 603 | aykhal
# Processing Record 475 of 603 | capreol
# Processing Record 476 of 603 | necochea
# Processing Record 477 of 603 | sangar
# City not found. Skipping....
# Processing Record 479 of 603 | carbonear
# Processing Record 480 of 603 | altay
# Processing Record 481 of 603 | linxia
# Processing Record 482 of 603 | fortuna
# Processing Record 483 of 603 | fort nelson
# Processing Record 484 of 603 | taonan
# City not found. Skipping....
# Processing Record 486 of 603 | atar
# Processing Record 487 of 603 | owando
# Processing Record 488 of 603 | sholapur
# Processing Record 489 of 603 | chaplynka
# Processing Record 490 of 603 | evensk
# Processing Record 491 of 603 | pittsfield
# Processing Record 492 of 603 | kushmurun
# Processing Record 493 of 603 | otaru
# Processing Record 494 of 603 | mawlaik
# Processing Record 495 of 603 | piombino
# Processing Record 496 of 603 | atherton
# Processing Record 497 of 603 | lavrentiya
# Processing Record 498 of 603 | kidal
# Processing Record 499 of 603 | kupang
# Processing Record 500 of 603 | sistranda
# Processing Record 501 of 603 | celestun
# Processing Record 502 of 603 | hell
# Processing Record 503 of 603 | mabaruma
# Processing Record 504 of 603 | puerto rico
# Processing Record 505 of 603 | yerbogachen
# Processing Record 506 of 603 | marawi
# Processing Record 507 of 603 | awbari
# Processing Record 508 of 603 | ambon
# Processing Record 509 of 603 | eureka
# Processing Record 510 of 603 | lodwar
# Processing Record 511 of 603 | dodge city
# Processing Record 512 of 603 | kirakira
# Processing Record 513 of 603 | tupaciguara
# Processing Record 514 of 603 | oranjemund
# Processing Record 515 of 603 | port hardy
# Processing Record 516 of 603 | dubbo
# Processing Record 517 of 603 | torbay
# Processing Record 518 of 603 | tarazona
# Processing Record 519 of 603 | braunau
# Processing Record 520 of 603 | leshukonskoye
# Processing Record 521 of 603 | manama
# City not found. Skipping....
# Processing Record 523 of 603 | bulgan
# City not found. Skipping....
# Processing Record 525 of 603 | kargil
# Processing Record 526 of 603 | xuddur
# Processing Record 527 of 603 | tornio
# Processing Record 528 of 603 | beboto
# Processing Record 529 of 603 | amapa
# Processing Record 530 of 603 | jibuti
# Processing Record 531 of 603 | cururupu
# Processing Record 532 of 603 | katsuura
# Processing Record 533 of 603 | rawson
# Processing Record 534 of 603 | brae
# Processing Record 535 of 603 | roebourne
# City not found. Skipping....
# Processing Record 537 of 603 | dembi dolo
# Processing Record 538 of 603 | namatanai
# Processing Record 539 of 603 | oga
# Processing Record 540 of 603 | maryville
# Processing Record 541 of 603 | shenjiamen
# City not found. Skipping....
# Processing Record 543 of 603 | boa vista
# Processing Record 544 of 603 | khani
# Processing Record 545 of 603 | suicheng
# Processing Record 546 of 603 | deming
# Processing Record 547 of 603 | talnakh
# City not found. Skipping....
# Processing Record 549 of 603 | myrhorod
# Processing Record 550 of 603 | talcahuano
# Processing Record 551 of 603 | aksu
# Processing Record 552 of 603 | visby
# Processing Record 553 of 603 | shubarshi
# Processing Record 554 of 603 | guatire
# Processing Record 555 of 603 | korla
# Processing Record 556 of 603 | uray
# Processing Record 557 of 603 | dunedin
# Processing Record 558 of 603 | hambantota
# City not found. Skipping....
# Processing Record 560 of 603 | hutchinson
# Processing Record 561 of 603 | itupiranga
# Processing Record 562 of 603 | russellville
# Processing Record 563 of 603 | paita
# Processing Record 564 of 603 | maraa
# City not found. Skipping....
# Processing Record 566 of 603 | marsa matruh
# Processing Record 567 of 603 | putina
# Processing Record 568 of 603 | havelock
# Processing Record 569 of 603 | luanda
# Processing Record 570 of 603 | tuatapere
# Processing Record 571 of 603 | akonolinga
# Processing Record 572 of 603 | pietarsaari
# Processing Record 573 of 603 | werda
# Processing Record 574 of 603 | ucar
# Processing Record 575 of 603 | keti bandar
# Processing Record 576 of 603 | ostrovnoy
# Processing Record 577 of 603 | kismayo
# Processing Record 578 of 603 | wilmington
# Processing Record 579 of 603 | sao goncalo
# Processing Record 580 of 603 | reinosa
# Processing Record 581 of 603 | andenes
# Processing Record 582 of 603 | desaguadero
# Processing Record 583 of 603 | kabul
# Processing Record 584 of 603 | pemba
# Processing Record 585 of 603 | padang
# Processing Record 586 of 603 | sisimiut
# Processing Record 587 of 603 | slantsy
# Processing Record 588 of 603 | jimani
# Processing Record 589 of 603 | severnyy
# Processing Record 590 of 603 | auki
# Processing Record 591 of 603 | dillon
# City not found. Skipping....
# Processing Record 593 of 603 | imeni poliny osipenko
# Processing Record 594 of 603 | lakes entrance
# Processing Record 595 of 603 | indian head
# Processing Record 596 of 603 | demyansk
# Processing Record 597 of 603 | sabha
# Processing Record 598 of 603 | ganzhou
# Processing Record 599 of 603 | herat
# Processing Record 600 of 603 | margate
# Processing Record 601 of 603 | mendota
# Processing Record 602 of 603 | pelym
# Processing Record 603 of 603 | vieste
# --------------------------------
# Data Retrieval Complete
# --------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({"City": city_name, "Lat":lat, "Lng":lng,"Max Temp": max_temp, 
                           "Humidity":humidity, "Cloudiness": cloud, "Wind Speed": wind_speed, 
                          "Country":country, "Date": date})
weather_df.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Chicama  -7.84  -79.15     64.40        77          90        9.17
# 1   Busselton -33.65  115.33     61.00        59           0        3.04
# 2      Sampit  -2.53  112.95     76.68        93         100        2.13
# 3        Orán -23.13  -64.33     78.01        37           0        1.99
# 4  Bredasdorp -34.53   20.04     53.60        62           0        4.70
#
#   Country        Date
# 0      PE  1604084130
# 1      AU  1604084130
# 2      ID  1604084027
# 3      AR  1604084130
# 4      ZA  1604083887

# %%
weather_df.to_csv('output.csv', index = False)

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  555.000000  555.000000  555.000000  555.000000  555.000000  555.000000
# mean    19.870162   19.582108   58.450955   70.859459   52.868468    7.843351
# std     33.797332   91.097732   23.001808   22.235572   41.248770    5.810492
# min    -54.800000 -179.170000  -11.900000    1.000000    0.000000    0.110000
# 25%     -8.055000  -60.225000   42.800000   58.000000    1.000000    3.360000
# 50%     24.140000   24.150000   64.000000   76.000000   68.000000    6.580000
# 75%     47.635000  100.085000   76.260000   88.000000   96.000000   10.470000
# max     78.220000  179.320000   97.660000  100.000000  100.000000   33.330000
#
#                Date
# count  5.550000e+02
# mean   1.604084e+09
# std    9.207034e+01
# min    1.604083e+09
# 25%    1.604084e+09
# 50%    1.604084e+09
# 75%    1.604084e+09
# max    1.604084e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
latitude = weather_df['Lat']
temperature = weather_df['Max Temp']

plt.scatter(latitude, temperature, edgecolor = "black")
plt.title("City Latitude vs. Max Temperature (30/10/20)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig('Images/Latitude_vs_ Temp.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
latitude = weather_df['Lat']
humidity = weather_df['Humidity']

plt.scatter(latitude, humidity, facecolor = 'red',edgecolor = "black")
plt.title("City Latitude vs. Humidity (30/10/20)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig('Images/Latitude_vs_ Humidity.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
latitude = weather_df['Lat']
cloudiness = weather_df['Cloudiness']

plt.scatter(latitude, cloudiness, facecolor = 'green',edgecolor = "black")
plt.title("City Latitude vs. Cloudiness (30/10/20)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig('Images/Latitude_vs_ Cloudiness.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
latitude = weather_df['Lat']
wind_speed = weather_df['Wind Speed']

plt.scatter(latitude, wind_speed, facecolor = 'orange',edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (30/10/20)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig('Images/Latitude_vs_ Wind.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
northern_hem = weather_df.loc[weather_df['Lat']>0]
southern_hem = weather_df.loc[weather_df['Lat']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
latitude = northern_hem['Lat']
temperature = northern_hem['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, temperature)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, temperature)
plt.title("Northern Hemisphere - Max Temp vs. Latitude")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(15,-20),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/NH_Latitude_vs_ Temp.png')
plt.show()
# Out:
# The r-value is: 0.7724820196028909

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
latitude = southern_hem['Lat']
temperature = southern_hem['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, temperature)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, temperature)
plt.title("Southern Hemisphere - Max Temp vs. Latitude")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(-20,50),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/SH_Latitude_vs_ Temp.png')
plt.show()
# Out:
# The r-value is: 0.4891682570060315

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
latitude = northern_hem['Lat']
humidity = northern_hem['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, humidity)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, humidity)
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/NH_Latitude_vs_ Humidity.png')
plt.show()
# Out:
# The r-value is: 0.11772788455823453

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
latitude = southern_hem['Lat']
humidity = southern_hem['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, humidity)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, humidity)
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/SH_Latitude_vs_ Humidity.png')
plt.show()
# Out:
# The r-value is: 0.005350601882732941

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
latitude = northern_hem['Lat']
cloudiness = northern_hem['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, cloudiness)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, cloudiness)
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(40,5),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/NH_Latitude_vs_ Cloudiness.png')
plt.show()
# Out:
# The r-value is: 0.02217672219272206

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
latitude = southern_hem['Lat']
cloudiness = southern_hem['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, cloudiness)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, cloudiness)
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(-55,25),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/SH_Latitude_vs_ Cloudiness.png')
plt.show()
# Out:
# The r-value is: 0.07906865127457323

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
latitude = northern_hem['Lat']
wind_speed = northern_hem['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, wind_speed)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, wind_speed)
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude")
plt.ylabel("Wind Speed(mph)")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(20,30),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/NH_Latitude_vs_ Wind.png')
plt.show()
# Out:
# The r-value is: 0.013033770977444679

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
latitude = southern_hem['Lat']
wind_speed = southern_hem['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, wind_speed)
regress_values = latitude * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))


plt.scatter(latitude, wind_speed)
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude")
plt.ylabel("Wind Speed(mph)")
plt.xlabel("Latitude")
plt.plot(latitude,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.tight_layout()
print(f"The r-value is: {rvalue**2}")
plt.savefig('Images/SH_Latitude_vs_ Wind.png')
plt.show()
# Out:
# The r-value is: 0.04383977965160686
